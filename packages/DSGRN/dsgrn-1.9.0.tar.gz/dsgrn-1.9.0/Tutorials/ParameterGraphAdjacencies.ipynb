# %%
import DSGRN

# %%
network = DSGRN.Network('X1 : (X1+X2)(~X3)\n X2 : (X1)\n X3 : (X1)(~X2)')

# %%
DSGRN.DrawGraph(network)

# %%
parametergraph = DSGRN.ParameterGraph(network)

# %%
print("There are " + str(parametergraph.size()) + " nodes in the parameter graph.")
# Out:
# There are 326592 nodes in the parameter graph.

# %%
par_index = 20

# %%
# Compute original DSGRN adjacencies
parametergraph.adjacencies(par_index)
# Out:
# [1, 21, 23, 34, 155, 776, 4556, 27236, 54452, 163316]

# %%
# Compute original DSGRN adjacencies
parametergraph.adjacencies(par_index, 'pre')
# Out:
# [1, 21, 23, 34, 155, 776, 4556, 27236, 54452, 163316]

# %%
# Compute DSGRN adjacencies for a fixed order parameter
parametergraph.adjacencies(par_index, 'fixedorder')
# Out:
# [1, 21, 23, 34, 155, 776, 4556]

# %%
# Compute DSGRN adjacencies for co-dim 1 order parameters
parametergraph.adjacencies(par_index, 'codim1')
# Out:
# [1, 21, 23, 34, 155, 776, 4556, 54452, 163316]

# %%
# Print the partial orders defining the parameter
parameter = parametergraph.parameter(par_index)
print(parameter.partialorders('T'))
# Out:
# X1 : (p0, p1, p2, p3, p4, p5, p6, T[X1->X1], T[X1->X2], p7, T[X1->X3])
# X2 : (p0, p1, T[X2->X1], T[X2->X3])
# X3 : (p0, p1, p2, p3, T[X3->X1])

# %%
# A shorter version of the partial orders defining the parameter
parameter = parametergraph.parameter(par_index)
print(parameter.partialorders())
# Out:
# X1 : (p0, p1, p2, p3, p4, p5, p6, t0, t1, p7, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)

# %%
# Print partial orders for pre order adjacencies
for p_index in parametergraph.adjacencies(par_index):
    parameter = parametergraph.parameter(p_index)
    print(parameter.partialorders())
    print('')
# Out:
# X1 : (p0, p1, p2, p3, p4, p5, p6, t0, p7, t1, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p4, p5, p6, t0, p3, t1, p7, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p6, t0, p5, t1, p7, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p5, t0, p6, t1, p7, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p5, p6, t0, t1, t2, p7)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p5, p6, t0, t1, p7, t2)
# X2 : (p0, t0, p1, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p5, p6, t0, t1, p7, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, t0, p3)
#
# X1 : (p0, p1, p2, p3, p4, p5, p6, t0, t2, p7, t1)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p5, p6, t1, t0, p7, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# ...

# %%
# Print partial orders for co-dim 1 order adjacencies
for p_index in parametergraph.adjacencies(par_index, 'codim1'):
    parameter = parametergraph.parameter(p_index)
    print(parameter.partialorders())
    print('')
# Out:
# X1 : (p0, p1, p2, p3, p4, p5, p6, t0, p7, t1, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p4, p5, p6, t0, p3, t1, p7, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p6, t0, p5, t1, p7, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p5, t0, p6, t1, p7, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p5, p6, t0, t1, t2, p7)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p5, p6, t0, t1, p7, t2)
# X2 : (p0, t0, p1, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p5, p6, t0, t1, p7, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, t0, p3)
#
# X1 : (p0, p1, p2, p3, p4, p5, p6, t1, t0, p7, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p5, p6, t0, t1, p7, t2)
# X2 : (p0, p1, t1, t0)
# X3 : (p0, p1, p2, p3, t0)

# %%
# Print partial orders for fixed orders adjacencies
for p_index in parametergraph.adjacencies(par_index, 'fixedorder'):
    parameter = parametergraph.parameter(p_index)
    print(parameter.partialorders())
    print('')
# Out:
# X1 : (p0, p1, p2, p3, p4, p5, p6, t0, p7, t1, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p4, p5, p6, t0, p3, t1, p7, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p6, t0, p5, t1, p7, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p5, t0, p6, t1, p7, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p5, p6, t0, t1, t2, p7)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p5, p6, t0, t1, p7, t2)
# X2 : (p0, t0, p1, t1)
# X3 : (p0, p1, p2, p3, t0)
#
# X1 : (p0, p1, p2, p3, p4, p5, p6, t0, t1, p7, t2)
# X2 : (p0, p1, t0, t1)
# X3 : (p0, p1, p2, t0, p3)

# %%
# Print parameters for pre order adjacencies
parameter = parametergraph.parameter(par_index)
print(parameter)
print('')

for p_index in parametergraph.adjacencies(par_index):
    parameter = parametergraph.parameter(p_index)
    print(parameter)
# Out:
# [["X1",[3,3,"600000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
#
# [["X1",[3,3,"200000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"600200"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"608000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"640000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"E00000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"600000"],[0,1,2]],["X2",[1,2,"4"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"600000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"8"],[0]]]
# [["X1",[3,3,"600000"],[0,2,1]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"600000"],[1,0,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"600000"],[0,1,2]],["X2",[1,2,"0"],[1,0]],["X3",[2,1,"0"],[0]]]

# %%
# Print parameters for co-dim 1 order adjacencies
parameter = parametergraph.parameter(par_index)
print(parameter)
print('')

for p_index in parametergraph.adjacencies(par_index, 'codim1'):
    parameter = parametergraph.parameter(p_index)
    print(parameter)
# Out:
# [["X1",[3,3,"600000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
#
# [["X1",[3,3,"200000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"600200"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"608000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"640000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"E00000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"600000"],[0,1,2]],["X2",[1,2,"4"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"600000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"8"],[0]]]
# [["X1",[3,3,"600000"],[1,0,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"600000"],[0,1,2]],["X2",[1,2,"0"],[1,0]],["X3",[2,1,"0"],[0]]]

# %%
# Print parameters for fixed orders adjacencies
parameter = parametergraph.parameter(par_index)
print(parameter)
print('')

# Notice that the orders are all the same of par_index
for p_index in parametergraph.adjacencies(par_index, 'fixedorder'):
    parameter = parametergraph.parameter(p_index)
    print(parameter)
# Out:
# [["X1",[3,3,"600000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
#
# [["X1",[3,3,"200000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"600200"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"608000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"640000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"E00000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"600000"],[0,1,2]],["X2",[1,2,"4"],[0,1]],["X3",[2,1,"0"],[0]]]
# [["X1",[3,3,"600000"],[0,1,2]],["X2",[1,2,"0"],[0,1]],["X3",[2,1,"8"],[0]]]

# %% [markdown]
# Let's see another example

# %%
par_index = 790

# %%
# Compute original DSGRN adjacencies
parametergraph.adjacencies(par_index)
# Out:
# [34, 762, 776, 791, 795, 836, 941, 1546, 2302, 5326, 28006, 55222, 164086]

# %%
# Compute DSGRN adjacencies for a fixed order parameter
parametergraph.adjacencies(par_index, 'fixedorder')
# Out:
# [34, 762, 776, 791, 795, 836, 941, 1546, 2302, 5326]

# %%
# Compute DSGRN adjacencies for co-dim 1 order parameters
parametergraph.adjacencies(par_index, 'codim1')
# Out:
# [34, 762, 776, 791, 795, 836, 941, 1546, 2302, 5326]

# %% [markdown]
# Notice that in this case the fixed order adjacent parameters are the same as the codim1. We can see why by looking at the partial orders defining the parameter. As we can see below there is no threshold swap that produces a co-dim 1 neighbor.

# %%
parameter = parametergraph.parameter(par_index)
print(parameter.partialorders('T'))
# Out:
# X1 : (p0, p1, p2, p3, p4, p5, T[X1->X1], p6, T[X1->X2], p7, T[X1->X3])
# X2 : (p0, T[X2->X1], p1, T[X2->X3])
# X3 : (p0, p1, p2, p3, T[X3->X1])

# %%
p_index = 28006
parameter = parametergraph.parameter(p_index)
print(parameter.partialorders('T'))
# Out:
# X1 : (p0, p1, p2, p3, p4, p5, T[X1->X1], p6, T[X1->X3], p7, T[X1->X2])
# X2 : (p0, T[X2->X1], p1, T[X2->X3])
# X3 : (p0, p1, p2, p3, T[X3->X1])
