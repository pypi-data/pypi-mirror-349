# %%
# Install DSGRN_utils
# !pip install --no-deps git+https://github.com/marciogameiro/DSGRN_utils.git
# Out:
# ...
#   Cloning https://github.com/marciogameiro/DSGRN_utils.git to /private/var/folders/ng/70_jjcwj71v34j9dwhwp0fk40000gn/T/pip-req-build-q7z086c7
#   Running command git clone --filter=blob:none --quiet https://github.com/marciogameiro/DSGRN_utils.git /private/var/folders/ng/70_jjcwj71v34j9dwhwp0fk40000gn/T/pip-req-build-q7z086c7
#   Resolved https://github.com/marciogameiro/DSGRN_utils.git to commit e94c3890553a17a2ab4f0cbf52e1d0c4ffe6201d
#   Preparing metadata (setup.py) ... done

# %%
import DSGRN
import DSGRN_utils

import time

# %% [markdown]
# ## Check if Morse graphs are isomorphic

# %%
net_spec = """x : x + y : B E
              y : (~x) y : B E"""

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Number of parameter nodes:', parameter_graph.size())
# Out:
# Number of parameter nodes: 16

# %%
par_index = 6

parameter = parameter_graph.parameter(par_index)

morse_graph1, stg1, graded_complex1 = DSGRN_utils.ConleyMorseGraph(parameter)

# %%
DSGRN_utils.PlotMorseGraph(morse_graph1)

# %%
par_index = 14

parameter = parameter_graph.parameter(par_index)

morse_graph2, stg2, graded_complex2 = DSGRN_utils.ConleyMorseGraph(parameter)

# %%
DSGRN_utils.PlotMorseGraph(morse_graph2)

# %% [markdown]
# Check if the Morse graphs are isomorphic.

# %%
# %%time
DSGRN.isomorphic_morse_graphs(morse_graph1, morse_graph2)
# Out:
# CPU times: user 10 μs, sys: 5 μs, total: 15 μs
# Wall time: 20 μs
# False

# %%
par_index = 2

parameter = parameter_graph.parameter(par_index)

morse_graph1, stg1, graded_complex1 = DSGRN_utils.ConleyMorseGraph(parameter)

# %%
DSGRN_utils.PlotMorseGraph(morse_graph1)

# %%
DSGRN_utils.PlotMorseSets(morse_graph1, stg1, graded_complex1)

# %%
par_index = 13

parameter = parameter_graph.parameter(par_index)

morse_graph2, stg2, graded_complex2 = DSGRN_utils.ConleyMorseGraph(parameter)

# %%
DSGRN_utils.PlotMorseGraph(morse_graph2)

# %%
DSGRN_utils.PlotMorseSets(morse_graph2, stg2, graded_complex2)

# %%
# %%time
DSGRN.isomorphic_morse_graphs(morse_graph1, morse_graph2)
# Out:
# CPU times: user 973 μs, sys: 158 μs, total: 1.13 ms
# Wall time: 1.14 ms
# True

# %%
net_spec = 'x : x + y + z : E\n y : (~x) (y + z) : E\n z : (~y) (x + z) : E'

network = DSGRN.Network(net_spec)

DSGRN.DrawGraph(network)

# %%
parameter_graph = DSGRN.ParameterGraph(network)

print('Number of parameter nodes:', parameter_graph.size())
# Out:
# Number of parameter nodes: 14624509392

# %%
par_index = 10672321721

parameter = parameter_graph.parameter(par_index)

morse_graph1, stg1, graded_complex1 = DSGRN_utils.ConleyMorseGraph(parameter)

# %%
DSGRN_utils.PlotMorseGraph(morse_graph1)

# %%
par_index = 10967221989

parameter = parameter_graph.parameter(par_index)

morse_graph2, stg2, graded_complex2 = DSGRN_utils.ConleyMorseGraph(parameter)

# %%
DSGRN_utils.PlotMorseGraph(morse_graph2)

# %%
# %%time
DSGRN.isomorphic_morse_graphs(morse_graph1, morse_graph2)
# Out:
# CPU times: user 933 μs, sys: 145 μs, total: 1.08 ms
# Wall time: 1.09 ms
# True

# %%
par_index = 5616446030

parameter = parameter_graph.parameter(par_index)

morse_graph3, stg3, graded_complex3 = DSGRN_utils.ConleyMorseGraph(parameter)

# %%
DSGRN_utils.PlotMorseGraph(morse_graph3)

# %%
# %%time
DSGRN.isomorphic_morse_graphs(morse_graph1, morse_graph3)
# Out:
# CPU times: user 22 μs, sys: 9 μs, total: 31 μs
# Wall time: 36.2 μs
# False
