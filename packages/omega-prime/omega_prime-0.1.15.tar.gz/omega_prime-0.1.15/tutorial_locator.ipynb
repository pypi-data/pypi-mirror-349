# %%
import numpy as np

import omega_prime

# %%
r = omega_prime.Recording.from_file("example_files/pedestrian.osi", xodr_path="example_files/fabriksgatan.xodr")

# %%
locator = omega_prime.Locator.from_mapodr(r.map)

# %%
xys = np.stack([r.moving_objects[0].x, r.moving_objects[0].y]).T
xys.shape
# Out:
# (434, 2)

# %%
sts = locator.xys2sts(xys)
sts
# Out:
# <xarray.Dataset> Size: 10kB
# Dimensions:      (time: 434)
# Dimensions without coordinates: time
# Data variables:
#     s            (time) float64 3kB 61.61 61.28 60.95 ... 13.69 13.69 13.69
#     t            (time) float64 3kB -0.001558 -0.001542 ... 0.0006931 0.0006931
#     roadlane_id  (time) object 3kB XodrLaneId(road_id='0', lane_id=1, section...

# %%
sts_poly = locator.xys2sts(xys, poly=r.moving_objects[0].polygon)
sts_poly
# Out:
# <xarray.Dataset> Size: 10kB
# Dimensions:      (time: 434)
# Dimensions without coordinates: time
# Data variables:
#     s            (time) float64 3kB 61.61 61.28 60.95 ... 13.69 13.69 13.69
#     t            (time) float64 3kB -0.001558 -0.001542 ... 0.0006931 0.0006931
#     roadlane_id  (time) object 3kB XodrLaneId(road_id='0', lane_id=1, section...

# %%
derived_xys = locator.sts2xys(sts)
derived_xys.shape
# Out:
# (434, 2)

# %%
derived_xys_poly = locator.sts2xys(sts_poly)
derived_xys_poly.shape
# Out:
# (434, 2)

# %%
np.max(np.linalg.norm(derived_xys - xys, axis=1))
# Out:
# np.float64(4.0283729338418126e-08)

# %%
# %matplotlib ipympl
# pip install ipympl
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.patches import Polygon as PltPolygon

_, ax = plt.subplots(1, 1)

for lid, l in r.map.lanes.items():
    ax.add_patch(PltPolygon(l.polygon.exterior.coords, fc="blue", alpha=0.2, ec="blue"))
ax.plot(*xys.T, label="xys", c="green")
ax.plot(*derived_xys_poly.T, label="derived_xys", c="yellow", linestyle="dashed")
ax.plot(*derived_xys.T, label="derived_xys", c="red", linestyle="dotted")
ax.autoscale()
ax.set_aspect(1)
ax.legend()
ax.set_xlim(-10, 50)
ax.set_ylim(-75, 0)
# Out:
# (-75.0, 0.0)

# %%
sts11 = locator.xys2lane_sts(lane_id=omega_prime.map_odr.XodrLaneId("0", 1, 0), xys=xys)
sts11.shape
# Out:
# (434, 2)
