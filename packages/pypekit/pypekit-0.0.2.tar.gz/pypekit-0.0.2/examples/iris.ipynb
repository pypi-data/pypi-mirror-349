# %%
from pypekit import Task
import pandas as pd


class IrisLoader(Task):
    input_types = {"source"}
    output_types = {"raw"}

    def run(self, _):
        from sklearn.datasets import load_iris
        iris = load_iris()
        iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
        iris_df['target'] = iris.target
        return iris_df


class TrainTestSplitter(Task):
    input_types = {"raw"}
    output_types = {"split"}

    def run(self, df):
        from sklearn.model_selection import train_test_split
        train_df, test_df = train_test_split(df, test_size=0.2)
        train_df['train'] = 1
        test_df['train'] = 0
        df = pd.concat([train_df, test_df], ignore_index=True)
        return df


class Scaler(Task):
    input_types = {"split"}
    output_types = {"processed"}

    def run(self, df):
        X = df.drop(columns=['target', 'train'])
        X_train = X[df['train'] == 1]

        scaler = self.get_scaler()
        scaler.fit(X_train)

        X_scaled = scaler.transform(X)
        scaled_df = pd.DataFrame(data=X_scaled, columns=X.columns)
        scaled_df['target'] = df['target']
        scaled_df['train'] = df['train']

        return scaled_df

    def get_scaler(self):
        raise NotImplementedError("Subclasses should implement this method.")


class MinMaxScaler(Scaler):
    def get_scaler(self):
        from sklearn.preprocessing import MinMaxScaler
        return MinMaxScaler()


class StandardScaler(Scaler):
    def get_scaler(self):
        from sklearn.preprocessing import StandardScaler
        return StandardScaler()


class PCA(Task):
    input_types = {"split", "processed"}
    output_types = {"processed"}

    def __init__(self, **kwargs):
        self.kwargs = kwargs

    def run(self, df):
        X = df.drop(columns=['target', 'train'])
        X_train = X[df['train'] == 1]

        from sklearn.decomposition import PCA
        pca = PCA(**self.kwargs)
        pca.fit(X_train)

        X_pca = pca.transform(X)
        pca_df = pd.DataFrame(data=X_pca, columns=[
                              f'PC{i+1}' for i in range(X_pca.shape[1])])
        pca_df['target'] = df['target']
        pca_df['train'] = df['train']

        return pca_df


class Classifier(Task):
    input_types = {"split", "processed"}
    output_types = {"processed", "predicted"}

    def run(self, df):
        X = df.drop(columns=['target', 'train'])
        y = df['target']
        X_train = X[df['train'] == 1]
        y_train = y[df['train'] == 1]

        classifier = self.get_classifier()
        classifier.fit(X_train, y_train)
        
        y_pred = classifier.predict(X)
        df['predicted'] = y_pred

        return df
    
    def get_scaler(self):
        raise NotImplementedError("Subclasses should implement this method.")


class LogisticRegression(Classifier):
    def __init__(self, **kwargs):
        self.kwargs = kwargs

    def get_classifier(self):
        from sklearn.linear_model import LogisticRegression
        return LogisticRegression(**self.kwargs)


class RandomForestClassifier(Classifier):
    def __init__(self, **kwargs):
        self.kwargs = kwargs

    def get_classifier(self):
        from sklearn.ensemble import RandomForestClassifier
        return RandomForestClassifier(**self.kwargs)


class SVC(Classifier):
    def __init__(self, **kwargs):
        self.kwargs = kwargs

    def get_classifier(self):
        from sklearn.svm import SVC
        return SVC(**self.kwargs)


class Evaluator(Task):
    input_types = {"predicted"}
    output_types = {"sink"}

    def run(self, df):
        df_test = df[df['train'] == 0]
        return (df_test['target'] == df_test['predicted']).mean()

# %%
from pypekit import Repository, CachedExecutor

repository = Repository({
    IrisLoader,
    TrainTestSplitter,
    MinMaxScaler,
    StandardScaler,
    PCA,
    LogisticRegression,
    RandomForestClassifier,
    SVC,
    Evaluator
})

repository.build_tree()
print(repository.build_tree_string())
# Out:
# └── Root
#     └── IrisLoader
#         └── TrainTestSplitter
#             ├── StandardScaler
#             │   ├── RandomForestClassifier
#             │   │   ├── Evaluator
#             │   │   ├── SVC
#             │   │   │   ├── Evaluator
#             │   │   │   ├── LogisticRegression
#             │   │   │   │   └── Evaluator
#             │   │   │   └── PCA
#             │   │   │       └── LogisticRegression
#             │   │   │           └── Evaluator
#             │   │   ├── LogisticRegression
#             │   │   │   ├── Evaluator
#             │   │   │   ├── SVC
#             │   │   │   │   └── Evaluator
#             │   │   │   └── PCA
#             │   │   │       └── SVC
#             │   │   │           └── Evaluator
#             │   │   └── PCA
#             │   │       ├── SVC
#             │   │       │   ├── Evaluator
#             │   │       │   └── LogisticRegression
#             │   │       │       └── Evaluator
#             │   │       └── LogisticRegression
#             │   │           ├── Evaluator
#             │   │           └── SVC
#             │   │               └── Evaluator
#             │   ├── SVC
#             │   │   ├── RandomForestClassifier
#             │   │   │   ├── Evaluator
#             │   │   │   ├── LogisticRegression
#             │   │   │   │   └── Evaluator
#             │   │   │   └── PCA
#             │   │   │       └── LogisticRegression
#             │   │   │           └── Evaluator
#             │   │   ├── Evaluator
#             │   │   ├── LogisticRegression
#             │   │   │   ├── Evaluator
#             │   │   │   ├── RandomForestClassifier
#             │   │   │   │   └── Evaluator
#             │   │   │   └── PCA
#             │   │   │       └── RandomForestClassifier
#             │   │   │           └── Evaluator
#             │   │   └── PCA
#             │   │       ├── RandomForestClassifier
#             │   │       │   ├── Evaluator
#             │   │       │   └── LogisticRegression
#             │   │       │       └── Evaluator
#             │   │       └── LogisticRegression
#             │   │           ├── Evaluator
#             │   │           └── RandomForestClassifier
#             │   │               └── Evaluator
#             │   ├── LogisticRegression
#             │   │   ├── RandomForestClassifier
#             │   │   │   ├── Evaluator
#             │   │   │   ├── SVC
#             │   │   │   │   └── Evaluator
#             │   │   │   └── PCA
#             │   │   │       └── SVC
#             │   │   │           └── Evaluator
#             │   │   ├── Evaluator
#             │   │   ├── SVC
#             │   │   │   ├── Evaluator
#             │   │   │   ├── RandomForestClassifier
#             │   │   │   │   └── Evaluator
#             │   │   │   └── PCA
#             │   │   │       └── RandomForestClassifier
#             │   │   │           └── Evaluator
#             │   │   └── PCA
#             │   │       ├── RandomForestClassifier
#             │   │       │   ├── Evaluator
#             │   │       │   └── SVC
#             │   │       │       └── Evaluator
#             │   │       └── SVC
#             │   │           ├── Evaluator
#             │   │           └── RandomForestClassifier
#             │   │               └── Evaluator
#             │   └── PCA
#             │       ├── RandomForestClassifier
#             │       │   ├── Evaluator
#             │       │   ├── SVC
#             │       │   │   ├── Evaluator
#             │       │   │   └── LogisticRegression
#             │       │   │       └── Evaluator
#             │       │   └── LogisticRegression
#             │       │       ├── Evaluator
#             │       │       └── SVC
#             │       │           └── Evaluator
#             │       ├── SVC
#             │       │   ├── Evaluator
#             │       │   ├── RandomForestClassifier
#             │       │   │   ├── Evaluator
#             │       │   │   └── LogisticRegression
#             │       │   │       └── Evaluator
#             │       │   └── LogisticRegression
#             │       │       ├── Evaluator
#             │       │       └── RandomForestClassifier
#             │       │           └── Evaluator
#             │       └── LogisticRegression
#             │           ├── Evaluator
#             │           ├── RandomForestClassifier
#             │           │   ├── Evaluator
#             │           │   └── SVC
#             │           │       └── Evaluator
#             │           └── SVC
#             │               ├── Evaluator
#             │               └── RandomForestClassifier
#             │                   └── Evaluator
#             ├── RandomForestClassifier
#             │   ├── Evaluator
#             │   ├── SVC
#             │   │   ├── Evaluator
#             │   │   ├── LogisticRegression
#             │   │   │   └── Evaluator
#             │   │   └── PCA
#             │   │       └── LogisticRegression
#             │   │           └── Evaluator
#             │   ├── LogisticRegression
#             │   │   ├── Evaluator
#             │   │   ├── SVC
#             │   │   │   └── Evaluator
#             │   │   └── PCA
#             │   │       └── SVC
#             │   │           └── Evaluator
#             │   └── PCA
#             │       ├── SVC
#             │       │   ├── Evaluator
#             │       │   └── LogisticRegression
#             │       │       └── Evaluator
#             │       └── LogisticRegression
#             │           ├── Evaluator
#             │           └── SVC
#             │               └── Evaluator
#             ├── MinMaxScaler
#             │   ├── RandomForestClassifier
#             │   │   ├── Evaluator
#             │   │   ├── SVC
#             │   │   │   ├── Evaluator
#             │   │   │   ├── LogisticRegression
#             │   │   │   │   └── Evaluator
#             │   │   │   └── PCA
#             │   │   │       └── LogisticRegression
#             │   │   │           └── Evaluator
#             │   │   ├── LogisticRegression
#             │   │   │   ├── Evaluator
#             │   │   │   ├── SVC
#             │   │   │   │   └── Evaluator
#             │   │   │   └── PCA
#             │   │   │       └── SVC
#             │   │   │           └── Evaluator
#             │   │   └── PCA
#             │   │       ├── SVC
#             │   │       │   ├── Evaluator
#             │   │       │   └── LogisticRegression
#             │   │       │       └── Evaluator
#             │   │       └── LogisticRegression
#             │   │           ├── Evaluator
#             │   │           └── SVC
#             │   │               └── Evaluator
#             │   ├── SVC
#             │   │   ├── RandomForestClassifier
#             │   │   │   ├── Evaluator
#             │   │   │   ├── LogisticRegression
#             │   │   │   │   └── Evaluator
#             │   │   │   └── PCA
#             │   │   │       └── LogisticRegression
#             │   │   │           └── Evaluator
#             │   │   ├── Evaluator
#             │   │   ├── LogisticRegression
#             │   │   │   ├── Evaluator
#             │   │   │   ├── RandomForestClassifier
#             │   │   │   │   └── Evaluator
#             │   │   │   └── PCA
#             │   │   │       └── RandomForestClassifier
#             │   │   │           └── Evaluator
#             │   │   └── PCA
#             │   │       ├── RandomForestClassifier
#             │   │       │   ├── Evaluator
#             │   │       │   └── LogisticRegression
#             │   │       │       └── Evaluator
#             │   │       └── LogisticRegression
#             │   │           ├── Evaluator
#             │   │           └── RandomForestClassifier
#             │   │               └── Evaluator
#             │   ├── LogisticRegression
#             │   │   ├── RandomForestClassifier
#             │   │   │   ├── Evaluator
#             │   │   │   ├── SVC
#             │   │   │   │   └── Evaluator
#             │   │   │   └── PCA
#             │   │   │       └── SVC
#             │   │   │           └── Evaluator
#             │   │   ├── Evaluator
#             │   │   ├── SVC
#             │   │   │   ├── Evaluator
#             │   │   │   ├── RandomForestClassifier
#             │   │   │   │   └── Evaluator
#             │   │   │   └── PCA
#             │   │   │       └── RandomForestClassifier
#             │   │   │           └── Evaluator
#             │   │   └── PCA
#             │   │       ├── SVC
#             │   │       │   ├── Evaluator
#             │   │       │   └── RandomForestClassifier
#             │   │       │       └── Evaluator
#             │   │       └── RandomForestClassifier
#             │   │           ├── Evaluator
#             │   │           └── SVC
#             │   │               └── Evaluator
#             │   └── PCA
#             │       ├── RandomForestClassifier
#             │       │   ├── Evaluator
#             │       │   ├── SVC
#             │       │   │   ├── Evaluator
#             │       │   │   └── LogisticRegression
#             │       │   │       └── Evaluator
#             │       │   └── LogisticRegression
#             │       │       ├── Evaluator
#             │       │       └── SVC
#             │       │           └── Evaluator
#             │       ├── SVC
#             │       │   ├── Evaluator
#             │       │   ├── RandomForestClassifier
#             │       │   │   ├── Evaluator
#             │       │   │   └── LogisticRegression
#             │       │   │       └── Evaluator
#             │       │   └── LogisticRegression
#             │       │       ├── Evaluator
#             │       │       └── RandomForestClassifier
#             │       │           └── Evaluator
#             │       └── LogisticRegression
#             │           ├── Evaluator
#             │           ├── SVC
#             │           │   ├── Evaluator
#             │           │   └── RandomForestClassifier
#             │           │       └── Evaluator
#             │           └── RandomForestClassifier
#             │               ├── Evaluator
#             │               └── SVC
#             │                   └── Evaluator
#             ├── SVC
#             │   ├── RandomForestClassifier
#             │   │   ├── Evaluator
#             │   │   ├── LogisticRegression
#             │   │   │   └── Evaluator
#             │   │   └── PCA
#             │   │       └── LogisticRegression
#             │   │           └── Evaluator
#             │   ├── Evaluator
#             │   ├── LogisticRegression
#             │   │   ├── RandomForestClassifier
#             │   │   │   └── Evaluator
#             │   │   ├── Evaluator
#             │   │   └── PCA
#             │   │       └── RandomForestClassifier
#             │   │           └── Evaluator
#             │   └── PCA
#             │       ├── RandomForestClassifier
#             │       │   ├── Evaluator
#             │       │   └── LogisticRegression
#             │       │       └── Evaluator
#             │       └── LogisticRegression
#             │           ├── Evaluator
#             │           └── RandomForestClassifier
#             │               └── Evaluator
#             ├── LogisticRegression
#             │   ├── RandomForestClassifier
#             │   │   ├── Evaluator
#             │   │   ├── SVC
#             │   │   │   └── Evaluator
#             │   │   └── PCA
#             │   │       └── SVC
#             │   │           └── Evaluator
#             │   ├── Evaluator
#             │   ├── SVC
#             │   │   ├── RandomForestClassifier
#             │   │   │   └── Evaluator
#             │   │   ├── Evaluator
#             │   │   └── PCA
#             │   │       └── RandomForestClassifier
#             │   │           └── Evaluator
#             │   └── PCA
#             │       ├── RandomForestClassifier
#             │       │   ├── Evaluator
#             │       │   └── SVC
#             │       │       └── Evaluator
#             │       └── SVC
#             │           ├── Evaluator
#             │           └── RandomForestClassifier
#             │               └── Evaluator
#             └── PCA
#                 ├── RandomForestClassifier
#                 │   ├── Evaluator
#                 │   ├── SVC
#                 │   │   ├── Evaluator
#                 │   │   └── LogisticRegression
#                 │   │       └── Evaluator
#                 │   └── LogisticRegression
#                 │       ├── Evaluator
#                 │       └── SVC
#                 │           └── Evaluator
#                 ├── SVC
#                 │   ├── RandomForestClassifier
#                 │   │   ├── Evaluator
#                 │   │   └── LogisticRegression
#                 │   │       └── Evaluator
#                 │   ├── Evaluator
#                 │   └── LogisticRegression
#                 │       ├── Evaluator
#                 │       └── RandomForestClassifier
#                 │           └── Evaluator
#                 └── LogisticRegression
#                     ├── RandomForestClassifier
#                     │   ├── Evaluator
#                     │   └── SVC
#                     │       └── Evaluator
#                     ├── Evaluator
#                     └── SVC
#                         ├── Evaluator
#                         └── RandomForestClassifier
#                             └── Evaluator

# %%
pipelines = repository.build_pipelines()
pipelines[:10]
# Out:
# [Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'SVC', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'SVC', 'LogisticRegression', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'SVC', 'PCA', 'LogisticRegression', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'LogisticRegression', 'SVC', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'LogisticRegression', 'PCA', 'SVC', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'PCA', 'SVC', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'PCA', 'SVC', 'LogisticRegression', 'Evaluator']),
#  Pipeline(tasks=['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'Evaluator'])]

# %%
executor = CachedExecutor(pipelines, verbose=True)
results = executor.run()
# Out:
# Pipeline 1/144 completed. Runtime: 1.07s.
# Pipeline 2/144 completed. Runtime: 1.08s.
# Pipeline 3/144 completed. Runtime: 1.10s.
# Pipeline 4/144 completed. Runtime: 1.09s.
# Pipeline 5/144 completed. Runtime: 1.08s.
# Pipeline 6/144 completed. Runtime: 1.08s.
# Pipeline 7/144 completed. Runtime: 1.08s.
# Pipeline 8/144 completed. Runtime: 1.08s.
# Pipeline 9/144 completed. Runtime: 1.08s.
# Pipeline 10/144 completed. Runtime: 1.08s.
# Pipeline 11/144 completed. Runtime: 1.08s.
# Pipeline 12/144 completed. Runtime: 0.94s.
# Pipeline 13/144 completed. Runtime: 0.94s.
# Pipeline 14/144 completed. Runtime: 0.94s.
# Pipeline 15/144 completed. Runtime: 0.87s.
# Pipeline 16/144 completed. Runtime: 0.87s.
# Pipeline 17/144 completed. Runtime: 0.96s.
# Pipeline 18/144 completed. Runtime: 0.94s.
# Pipeline 19/144 completed. Runtime: 0.93s.
# Pipeline 20/144 completed. Runtime: 0.94s.
# Pipeline 21/144 completed. Runtime: 0.88s.
# Pipeline 22/144 completed. Runtime: 0.95s.
# Pipeline 23/144 completed. Runtime: 0.96s.
# Pipeline 24/144 completed. Runtime: 0.96s.
# Pipeline 25/144 completed. Runtime: 0.96s.
# Pipeline 26/144 completed. Runtime: 0.88s.
# Pipeline 27/144 completed. Runtime: 0.88s.
# Pipeline 28/144 completed. Runtime: 0.93s.
# Pipeline 29/144 completed. Runtime: 0.94s.
# Pipeline 30/144 completed. Runtime: 0.94s.
# Pipeline 31/144 completed. Runtime: 0.94s.
# Pipeline 32/144 completed. Runtime: 0.88s.
# Pipeline 33/144 completed. Runtime: 0.94s.
# Pipeline 34/144 completed. Runtime: 0.93s.
# Pipeline 35/144 completed. Runtime: 0.93s.
# Pipeline 36/144 completed. Runtime: 0.94s.
# Pipeline 37/144 completed. Runtime: 0.94s.
# Pipeline 38/144 completed. Runtime: 0.94s.
# Pipeline 39/144 completed. Runtime: 0.88s.
# Pipeline 40/144 completed. Runtime: 0.96s.
# Pipeline 41/144 completed. Runtime: 0.96s.
# Pipeline 42/144 completed. Runtime: 0.88s.
# Pipeline 43/144 completed. Runtime: 0.95s.
# Pipeline 44/144 completed. Runtime: 0.88s.
# Pipeline 45/144 completed. Runtime: 0.94s.
# Pipeline 46/144 completed. Runtime: 0.95s.
# Pipeline 47/144 completed. Runtime: 0.88s.
# Pipeline 48/144 completed. Runtime: 0.94s.
# Pipeline 49/144 completed. Runtime: 0.92s.
# Pipeline 50/144 completed. Runtime: 0.92s.
# Pipeline 51/144 completed. Runtime: 0.93s.
# Pipeline 52/144 completed. Runtime: 0.93s.
# Pipeline 53/144 completed. Runtime: 0.94s.
# Pipeline 54/144 completed. Runtime: 0.94s.
# Pipeline 55/144 completed. Runtime: 0.94s.
# Pipeline 56/144 completed. Runtime: 0.92s.
# Pipeline 57/144 completed. Runtime: 0.93s.
# Pipeline 58/144 completed. Runtime: 0.93s.
# Pipeline 59/144 completed. Runtime: 0.93s.
# Pipeline 60/144 completed. Runtime: 0.94s.
# Pipeline 61/144 completed. Runtime: 0.94s.
# Pipeline 62/144 completed. Runtime: 0.95s.
# Pipeline 63/144 completed. Runtime: 0.95s.
# Pipeline 64/144 completed. Runtime: 0.95s.
# Pipeline 65/144 completed. Runtime: 0.95s.
# Pipeline 66/144 completed. Runtime: 0.95s.
# Pipeline 67/144 completed. Runtime: 0.95s.
# Pipeline 68/144 completed. Runtime: 0.95s.
# Pipeline 69/144 completed. Runtime: 0.95s.
# Pipeline 70/144 completed. Runtime: 0.95s.
# Pipeline 71/144 completed. Runtime: 0.96s.
# Pipeline 72/144 completed. Runtime: 0.96s.
# Pipeline 73/144 completed. Runtime: 0.96s.
# Pipeline 74/144 completed. Runtime: 0.87s.
# Pipeline 75/144 completed. Runtime: 0.87s.
# Pipeline 76/144 completed. Runtime: 0.95s.
# Pipeline 77/144 completed. Runtime: 0.93s.
# Pipeline 78/144 completed. Runtime: 0.93s.
# Pipeline 79/144 completed. Runtime: 0.93s.
# Pipeline 80/144 completed. Runtime: 0.87s.
# Pipeline 81/144 completed. Runtime: 0.94s.
# Pipeline 82/144 completed. Runtime: 0.95s.
# Pipeline 83/144 completed. Runtime: 0.96s.
# Pipeline 84/144 completed. Runtime: 0.96s.
# Pipeline 85/144 completed. Runtime: 0.87s.
# Pipeline 86/144 completed. Runtime: 0.87s.
# Pipeline 87/144 completed. Runtime: 0.93s.
# Pipeline 88/144 completed. Runtime: 0.93s.
# Pipeline 89/144 completed. Runtime: 0.88s.
# Pipeline 90/144 completed. Runtime: 0.94s.
# Pipeline 91/144 completed. Runtime: 0.93s.
# Pipeline 92/144 completed. Runtime: 0.94s.
# Pipeline 93/144 completed. Runtime: 0.93s.
# Pipeline 94/144 completed. Runtime: 0.93s.
# Pipeline 95/144 completed. Runtime: 0.94s.
# Pipeline 96/144 completed. Runtime: 0.93s.
# Pipeline 97/144 completed. Runtime: 0.93s.
# Pipeline 98/144 completed. Runtime: 0.87s.
# Pipeline 99/144 completed. Runtime: 0.94s.
# Pipeline 100/144 completed. Runtime: 0.94s.
# Pipeline 101/144 completed. Runtime: 0.87s.
# Pipeline 102/144 completed. Runtime: 0.95s.
# Pipeline 103/144 completed. Runtime: 0.87s.
# Pipeline 104/144 completed. Runtime: 0.87s.
# Pipeline 105/144 completed. Runtime: 0.96s.
# Pipeline 106/144 completed. Runtime: 0.93s.
# Pipeline 107/144 completed. Runtime: 0.94s.
# Pipeline 108/144 completed. Runtime: 0.93s.
# Pipeline 109/144 completed. Runtime: 0.93s.
# Pipeline 110/144 completed. Runtime: 0.93s.
# Pipeline 111/144 completed. Runtime: 0.87s.
# Pipeline 112/144 completed. Runtime: 0.94s.
# Pipeline 113/144 completed. Runtime: 0.88s.
# Pipeline 114/144 completed. Runtime: 0.94s.
# Pipeline 115/144 completed. Runtime: 0.93s.
# Pipeline 116/144 completed. Runtime: 0.93s.
# Pipeline 117/144 completed. Runtime: 0.87s.
# Pipeline 118/144 completed. Runtime: 0.95s.
# Pipeline 119/144 completed. Runtime: 0.96s.
# Pipeline 120/144 completed. Runtime: 0.96s.
# Pipeline 121/144 completed. Runtime: 0.96s.
# Pipeline 122/144 completed. Runtime: 0.88s.
# Pipeline 123/144 completed. Runtime: 0.93s.
# Pipeline 124/144 completed. Runtime: 0.88s.
# Pipeline 125/144 completed. Runtime: 0.94s.
# Pipeline 126/144 completed. Runtime: 0.94s.
# Pipeline 127/144 completed. Runtime: 0.94s.
# Pipeline 128/144 completed. Runtime: 0.88s.
# Pipeline 129/144 completed. Runtime: 0.94s.
# Pipeline 130/144 completed. Runtime: 0.93s.
# Pipeline 131/144 completed. Runtime: 0.93s.
# Pipeline 132/144 completed. Runtime: 0.93s.
# Pipeline 133/144 completed. Runtime: 0.93s.
# Pipeline 134/144 completed. Runtime: 0.93s.
# Pipeline 135/144 completed. Runtime: 0.95s.
# Pipeline 136/144 completed. Runtime: 0.95s.
# Pipeline 137/144 completed. Runtime: 0.87s.
# Pipeline 138/144 completed. Runtime: 0.87s.
# Pipeline 139/144 completed. Runtime: 0.95s.
# Pipeline 140/144 completed. Runtime: 0.95s.
# Pipeline 141/144 completed. Runtime: 0.96s.
# Pipeline 142/144 completed. Runtime: 0.87s.
# Pipeline 143/144 completed. Runtime: 0.87s.
# Pipeline 144/144 completed. Runtime: 0.93s.

# %%
for r in results:
    print(r)
# Out:
# {'output': np.float64(0.9333333333333333), 'runtime': 1.072426192000421, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 1.076065772003858, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 1.0960505390030448, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 1.0868052160039952, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'SVC', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 1.0750804270010121, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 1.0773056750022079, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 1.0787338000009186, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'LogisticRegression', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 1.0782689999996364, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 1.0814604150000378, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'PCA', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 1.076354197002729, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 1.0779472140020516, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9377784600001178, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9404813660021318, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9422454370014748, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.871460284000932, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.8741801520009176, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9566795120008464, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9374587439997413, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9332880769998155, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9385077469996759, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.8763369110001804, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9468914379995113, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'SVC', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9586300169994502, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.961533313999098, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9615244969972991, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'RandomForestClassifier', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.8788379340003303, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.88036543599992, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.932778528000199, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9399309310028912, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'SVC', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.937601674000689, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9400007230015035, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.8828087889996823, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9447608000009495, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'LogisticRegression', 'PCA', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9312838390032994, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9338754440032062, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9380845130017406, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'RandomForestClassifier', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9367775290011195, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.93972158300312, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.8752499750007701, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9562991650018375, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.960088056001041, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'SVC', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.8783717469996191, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9516761710019637, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'SVC', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.8768956830026582, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9444459610003832, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9464326970010006, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.878696095003761, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9364001200028724, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'StandardScaler', 'PCA', 'LogisticRegression', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9203601790013636, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9221809700011363, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9305844900009106, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9308789030019398, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'SVC', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.937471187000483, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9407360300010623, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9416699459998199, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'LogisticRegression', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9237793770007556, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9271513860021514, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'PCA', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9254555930019706, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9276732870039268, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9410140520030836, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9426631970018207, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.94632905400249, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9496074180005962, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'SVC', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9467513050021807, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9495312580020254, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.952510319000794, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'LogisticRegression', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9462138230010169, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9499099459990248, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'PCA', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9470129110031849, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9494512360033696, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9559364190008637, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.963003099001071, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9635304589992302, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8705319590008003, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8747504349994415, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9541382379993593, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9313113630014414, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9282538620027481, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9333141170009185, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8747905000000173, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9408160940001835, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'SVC', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9530560830007744, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9552017709993379, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9571609029990213, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'RandomForestClassifier', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8721725040013553, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8740014200011501, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9312562360009906, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9338488600023993, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'SVC', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8751412250021531, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9357990780026739, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'PCA', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9343561750010849, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9361247860015283, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9333333333333333), 'runtime': 0.9294372500007739, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9318599440011894, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.935802035000961, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'RandomForestClassifier', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.931929365000542, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9337910519989236, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8713050469996233, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9402638819992717, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.943371956996998, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'SVC', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.87487121400045, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9511643539990473, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'SVC', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.872775020001427, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8746110280007997, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9555176980011311, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'LogisticRegression', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9330966620000254, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9350478890028171, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'MinMaxScaler', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.925103958001273, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9325501960029214, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9296288360001199, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'RandomForestClassifier', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8678858510011196, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9440634429975034, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8751091469985113, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9381911749987921, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9295762659985485, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9336837610007933, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8741418890003843, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9523179790030554, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'SVC', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9556780120001349, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9583717810000962, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9587120380019769, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'RandomForestClassifier', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8777679979993991, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9337392840006942, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8794720469995809, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9420584020008391, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'SVC', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9391842309996719, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9412913340020168, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'PCA', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8816905719995702, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9389615479994973, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'LogisticRegression', 'PCA', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9251588990009623, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9267775840016839, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9303376590032713, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'RandomForestClassifier', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9280308050019812, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9305724560017552, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'RandomForestClassifier', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9483856360002392, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'SVC', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9527872099988599, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'SVC', 'RandomForestClassifier', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8707655819998763, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8740920120017108, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'SVC', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9466610670024238, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'SVC', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9546550390004995, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9575638259993866, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'LogisticRegression', 'RandomForestClassifier', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8719691090009292, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'LogisticRegression', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.8742858810019243, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'LogisticRegression', 'SVC', 'Evaluator']}
# {'output': np.float64(0.9666666666666667), 'runtime': 0.9324586190014088, 'tasks': ['IrisLoader', 'TrainTestSplitter', 'PCA', 'LogisticRegression', 'SVC', 'RandomForestClassifier', 'Evaluator']}
