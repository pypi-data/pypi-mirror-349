# %%
# import packages
from deabook import MQDEA
from deabook.constant import CET_ADDI, RTS_VRS1, RTS_CRS, \
                        OPT_LOCAL,TOTAL,CONTEMPORARY

import pandas as pd
# import all data (including the contextual varibale)
from pandas.api.types import CategoricalDtype
cat_size_order = CategoricalDtype(
    ['MQ', 'MEFFCH', 'MTECHCH'], 
    ordered=True
)


kind = "province" # "province" or "country"

if kind == "province":
    dmuname = '省份'
    data = pd.read_excel(r"../../data\china data.xlsx").query('year>2015').reset_index(drop=True)
    region = data[["省份","group"]]
else:
    dmuname = '国家'
    data = pd.read_excel(r"../../data\oecd data.xlsx").query('year>2015').reset_index(drop=True)


yearid = data[['year',dmuname]]
yearid
# Out:
#      year    省份
# 0    2016   上海市
# 1    2017   上海市
# 2    2018   上海市
# 3    2019   上海市
# 4    2016   云南省
# ..    ...   ...
# 115  2019   青海省
# 116  2016  黑龙江省
# 117  2017  黑龙江省
# 118  2018  黑龙江省
# 119  2019  黑龙江省
#
# [120 rows x 2 columns]

# %%
data
# Out:
#        省份  year           Y             E        L             K         CO2  \
# 0     上海市  2016  902.794998  11286.777262  1365.24  4.085533e+06  188.140000
# 1     上海市  2017  929.498785  11423.298889  1372.65  4.238459e+06  190.480000
# 2     上海市  2018  951.911601  11072.057032  1375.66  5.790083e+06  190.641610
# 3     上海市  2019  947.300532  11536.380416  1376.20  6.373635e+06  192.912182
# 4     云南省  2016  427.550554   9360.041199  2855.00  4.787612e+06  180.050000
# ..    ...   ...         ...           ...      ...           ...         ...
# 115   青海省  2019   62.322152   3566.776509   330.20  1.164860e+06   51.752403
# 116  黑龙江省  2016  394.193978   9307.525536  1776.00  4.500560e+06  269.340000
# 117  黑龙江省  2017  384.949317   9192.427176  1699.00  4.867986e+06  268.660000
# 118  黑龙江省  2018  384.333468   7514.188572  1635.00  4.611428e+06  248.035933
# 119  黑龙江省  2019  389.627692   8356.804833  1551.00  4.770895e+06  278.211338
#
#     group
# 0       E
# 1       E
# 2       E
# 3       E
# 4       W
# ..    ...
# 115     W
# 116     C
# 117     C
# 118     C
# 119     C
#
# [120 rows x 8 columns]

# %%
yearid[dmuname].unique()
# Out:
# array(['上海市', '云南省', '内蒙古自治区', '北京市', '吉林省', '四川省', '天津市', '宁夏回族自治区',
#        '安徽省', '山东省', '山西省', '广东省', '广西壮族自治区', '新疆维吾尔自治区', '江苏省', '江西省',
#        '河北省', '河南省', '浙江省', '海南省', '湖北省', '湖南省', '甘肃省', '福建省', '贵州省',
#        '辽宁省', '重庆市', '陕西省', '青海省', '黑龙江省'], dtype=object)

# %%
ssss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 ssss
#
# NameError: name 'ssss' is not defined

# %% [markdown]
# ## MQDEA

# %%
def MQDEA_VRS():

    # model = DEA.DEA(data,sent = "K L E=Y:CO2",  orient="L", rts=RTS_VRS, baseindex=None,refindex=None)
    model = MQDEA.MQDEA(data,id=dmuname,year='year',sent = "K L E=Y",  gx=[0,0,1],gy=[0], rts=RTS_VRS1,\
                        tech = CONTEMPORARY,email = OPT_LOCAL,solver="mosek")
    res = model.optimize()
    # print(model.info(1))
    return res
MQDEA_VRS = MQDEA_VRS()
MQDEA_VRS
# Out:
# Calculating CONTEMPORARY tech components (D11, D12, D21)...
#   Evaluating year 2016 against year 2016 (D11 component)...
# Optimizing locally.
#   Evaluating year 2017 against year 2017 (D11 component)...
# Optimizing locally.
#   Evaluating year 2018 against year 2018 (D11 component)...
# Optimizing locally.
#   Evaluating year 2019 against year 2019 (D11 component)...
# Optimizing locally.
#   Evaluating year 2017 against year 2016 (D12 component)...
# Optimizing locally.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 1, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 13, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 29, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 45, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 57, optimization_status :warning
#   Evaluating year 2018 against year 2017 (D12 component)...
# Optimizing locally.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 2, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 14, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 30, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 46, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 58, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 114, optimization_status :warning
#   Evaluating year 2019 against year 2018 (D12 component)...
# Optimizing locally.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 15, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 31, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 47, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 115, optimization_status :warning
#   Evaluating year 2016 against year 2017 (D21 component)...
# Optimizing locally.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 0, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 12, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 28, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 44, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 76, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 112, optimization_status :warning
#   Evaluating year 2017 against year 2018 (D21 component)...
# Optimizing locally.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 1, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 13, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 29, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 45, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 77, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 113, optimization_status :warning
#   Evaluating year 2018 against year 2019 (D21 component)...
# Optimizing locally.
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 2, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 14, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 30, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 58, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 78, optimization_status :warning
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: infeasible
#     - message from solver:  Problem is primal infeasible. The solution is a
#       certificate of primal infeasibility.
# Error optimizing DMU 114, optimization_status :warning
# CONTEMPORARY tech calculation finished.
#        省份  year           Y             E        L             K         CO2  \
# 0     上海市  2016  902.794998  11286.777262  1365.24  4.085533e+06  188.140000
# 1     上海市  2017  929.498785  11423.298889  1372.65  4.238459e+06  190.480000
# 2     上海市  2018  951.911601  11072.057032  1375.66  5.790083e+06  190.641610
# 3     上海市  2019  947.300532  11536.380416  1376.20  6.373635e+06  192.912182
# 4     云南省  2016  427.550554   9360.041199  2855.00  4.787612e+06  180.050000
# ..    ...   ...         ...           ...      ...           ...         ...
# 115   青海省  2019   62.322152   3566.776509   330.20  1.164860e+06   51.752403
# 116  黑龙江省  2016  394.193978   9307.525536  1776.00  4.500560e+06  269.340000
# 117  黑龙江省  2017  384.949317   9192.427176  1699.00  4.867986e+06  268.660000
# 118  黑龙江省  2018  384.333468   7514.188572  1635.00  4.611428e+06  248.035933
# 119  黑龙江省  2019  389.627692   8356.804833  1551.00  4.770895e+06  278.211338
#
#     group       D11       D12       D21        MQ    MEFFCH   MTECHCH
# 0       E  1.000000       NaN       NaN       NaN       NaN       NaN
# 1       E  1.000000       NaN       NaN       NaN  1.000000       NaN
# 2       E  1.000000       NaN       NaN       NaN  1.000000       NaN
# 3       E  1.000000  0.920979       NaN       NaN  1.000000       NaN
# 4       W  0.395443       NaN  0.395127       NaN       NaN       NaN
# ..    ...       ...       ...       ...       ...       ...       ...
# 115     W  1.000000       NaN       NaN       NaN  1.000000       NaN
# 116     C  0.378062       NaN  0.378004       NaN       NaN       NaN
# 117     C  0.377307  0.377292  0.385382  0.998059  0.998004  1.000056
# 118     C  0.471020  0.461133  0.483587  1.222192  1.248372  0.979028
# 119     C  0.438125  0.426888       NaN  0.906148  0.930163  0.974182
#
# [120 rows x 14 columns]

# %%
MQDEA_VRS2 = MQDEA_VRS[['year',dmuname,'MQ',	'MEFFCH',	'MTECHCH']]

# %%
MQDEA_VRS2.query('year==2017').sort_values('MQ')
# Out:
#      year        省份        MQ    MEFFCH   MTECHCH
# 105  2017       重庆市  0.954455  0.955141  0.999281
# 61   2017       江西省  0.957370  0.956487  1.000923
# 53   2017  新疆维吾尔自治区  0.968826  0.971582  0.997164
# 85   2017       湖南省  0.971833  0.967328  1.004657
# 101  2017       辽宁省  0.975362  0.971089  1.004400
# 49   2017   广西壮族自治区  0.975921  0.974606  1.001350
# 5    2017       云南省  0.976012  0.975112  1.000923
# 81   2017       湖北省  0.991688  0.986563  1.005194
# 89   2017       甘肃省  0.993724  0.999877  0.993847
# 117  2017      黑龙江省  0.998059  0.998004  1.000056
# 93   2017       福建省  0.999175  0.994683  1.004516
# 97   2017       贵州省  1.000188  1.003201  0.996996
# 33   2017       安徽省  1.001920  0.998125  1.003802
# 37   2017       山东省  1.009232  0.990154  1.019268
# 73   2017       浙江省  1.010619  0.986068  1.024897
# 9    2017    内蒙古自治区  1.015133  1.017982  0.997202
# 65   2017       河北省  1.023525  0.984155  1.040004
# 109  2017       陕西省  1.033141  1.031734  1.001363
# 21   2017       四川省  1.038471  1.022964  1.015159
# 41   2017       山西省  1.043033  1.041917  1.001071
# 17   2017       吉林省  1.046735  1.048043  0.998752
# 25   2017       天津市  1.075766  1.078290  0.997659
# 69   2017       河南省  1.085286  1.045903  1.037655
# 1    2017       上海市       NaN  1.000000       NaN
# 13   2017       北京市       NaN  1.000000       NaN
# 29   2017   宁夏回族自治区       NaN  1.000000       NaN
# 45   2017       广东省       NaN  1.000000       NaN
# 57   2017       江苏省       NaN  1.000000       NaN
# 77   2017       海南省       NaN  1.000000       NaN
# 113  2017       青海省       NaN  1.000000       NaN

# %%
MQDEA_VRS3 = MQDEA_VRS2.query('year>2016').pivot_table(
    values=['MQ',	'MEFFCH',	'MTECHCH'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)    [['MEFFCH','MTECHCH','MQ']]

# %%
MQDEA_VRS3.to_markdown("MQDEA_VRS_.md")

# %%
SSS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 SSS
#
# NameError: name 'SSS' is not defined

# %% [markdown]
# 
# 江苏省            NaN       NaN       NaN
# 江西省       0.957370  0.992737  0.970574
# 河北省       1.023525  0.868502  1.008644
# 河南省       1.085286  1.066894  1.035903
# 浙江省       1.010619  1.024636  0.984680
# 海南省            NaN       NaN       NaN
# 湖北省       0.991688  1.046571  0.968218
# 湖南省       0.971833  1.031754  0.987849
# 甘肃省       0.993724  0.990177  1.004062
# 福建省       0.999175  1.003803  0.960052
# 贵州省       1.000188  1.023699  0.976158
# 辽宁省       0.975362  0.973811  0.951864
# 重庆市       0.954455  1.000873  1.029719
# 陕西省       1.033141  0.987884  0.943189
# 青海省            NaN       NaN       NaN
# 黑龙江省      0.998059  1.222192  0.906148

# %%
MQ_mean_year = MQDEA_VRS3['MQ'].mean()
MEFFCH_mean_year = MQDEA_VRS3['MEFFCH'].mean()
MTECHCH_mean_year = MQDEA_VRS3['MTECHCH'].mean()

# %%
MTECHCH_mean_year
# Out:
# year
# 2017    1.006354
# 2018    0.986258
# 2019    0.985032
# dtype: float64

# %%
MEFFCH_mean_year
# Out:
# year
# 2017    0.999967
# 2018    1.015507
# 2019    0.988078
# dtype: float64

# %%
MQ_mean_year
# Out:
# year
# 2017    1.006325
# 2018    1.005998
# 2019    0.969539
# dtype: float64

# %%
xtick2 = tuple(MQ_mean_year.index)

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib notebook
# plt.figure(figsize=(1,1))
params = {
    'figure.figsize': '8, 4'
}
# plt.rcParams.update(params)
# plt.rc('font',family='Times New Roman')
from matplotlib import rcParams
rcParams['font.family'] = 'SimHei'


import numpy as np

# %%
fig, ax = plt.subplots() # 创建图形网格


ax.spines['top'].set_visible(False) # 使上边框不可见
ax.spines['right'].set_visible(False)
# ax2.spines['right'].set_visible(False)

################################ 绘图 #################################

n_groups = 3 # 样本的数目（ref，mut1-3）
index = np.arange(n_groups) # 转换为列表
bar_width = 0.5 # 设置柱子的宽度
# opacity = 0.8 # 设置柱子的透明度
error_config = {'ecolor': 'black','capsize' :2} # 设置误差线为黑色，宽度为2



# 画第一个样本的柱子
rects1 = ax.plot(index, MQ_mean_year,
                color='darkblue',alpha = 0.8,linestyle = "dashed",marker = "s",label='MQ'
            #      error_kw=error_config,
            #   edgecolor = 'white'
              )
rects2 = ax.plot(index, MEFFCH_mean_year,
                color='olivedrab',alpha = 0.8,linestyle = "dashed",marker = "^",label='MEFFCH'
            #      error_kw=error_config,
            #   edgecolor = 'white'
              )
rects3 = ax.plot(index, MTECHCH_mean_year,
                color='orange',alpha = 0.8,linestyle = "dashed",marker = "+",label='MTECHCH'
            #      error_kw=error_config,
            #   edgecolor = 'white'
              )
###########################################333

# ax.set_xlabel('Hours in 4 ℃')
ax.set_ylabel( r'$\mathregular{能源效率}$')
#  r'$Difficulty of reducing emissions \gamma$' 
# ax.set_title('Creat by python')
ax.set_xticks(index )
ax.set_xticklabels(xtick2)
# ax2.set_xlabel('Relative gene expression')
# ax.spines["bottom"].set_position(("data",0))
plt.legend()#borderaxespad=10,loc='upper right', fontsize='x-large'mode='expand'

plt.xticks(rotation=80)    # x 轴刻度添加80度旋转
# ax.legend(frameon=False,loc='best',ncol = 1)
if kind=="province":
   plt.savefig("chap42分年份能源效率-省.png", dpi=900, bbox_inches = 'tight')
else:
   plt.savefig("chap42分年份能源效率-国.png", dpi=900, bbox_inches = 'tight')
plt.show()
# Out:
# <div id='7efae536-dc4d-4e07-bdaa-be9d039bd19d'></div>

# %%
MQ_mean_cou = MQDEA_VRS3['MQ'].mean(axis=1)
MEFFCH_mean_cou = MQDEA_VRS3['MEFFCH'].mean(axis=1)
MTECHCH_mean_cou = MQDEA_VRS3['MTECHCH'].mean(axis=1)

# %%
MQ_mean_cou
# Out:
# 省份
# 上海市              NaN
# 云南省         0.961449
# 内蒙古自治区      0.932213
# 北京市              NaN
# 吉林省         1.027661
# 四川省         1.027041
# 天津市         1.013782
# 宁夏回族自治区          NaN
# 安徽省         0.998662
# 山东省         0.957950
# 山西省         0.994686
# 广东省              NaN
# 广西壮族自治区     0.982744
# 新疆维吾尔自治区    0.979745
# 江苏省              NaN
# 江西省         0.973560
# 河北省         0.966890
# 河南省         1.062695
# 浙江省         1.006645
# 海南省              NaN
# 湖北省         1.002159
# 湖南省         0.997145
# 甘肃省         0.995988
# 福建省         0.987677
# 贵州省         1.000015
# 辽宁省         0.967012
# 重庆市         0.995015
# 陕西省         0.988071
# 青海省              NaN
# 黑龙江省        1.042133
# dtype: float64

# %%
zz = pd.concat([MQ_mean_cou,MEFFCH_mean_cou],axis=1).sort_values(0).rename(columns= {0:2})
zz = pd.concat([zz,MTECHCH_mean_cou],axis=1) 

MQ_mean_cou = zz[2]
MEFFCH_mean_cou = zz[1]
MTECHCH_mean_cou = zz[0]
zz
# Out:
#                  2         1         0
# 省份
# 内蒙古自治区    0.932213  0.951778  0.978867
# 山东省       0.957950  0.951456  1.006627
# 云南省       0.961449  0.973789  0.987332
# 河北省       0.966890  0.942861  1.025494
# 辽宁省       0.967012  0.971831  0.995035
# 江西省       0.973560  0.986534  0.987047
# 新疆维吾尔自治区  0.979745  1.000346  0.979611
# 广西壮族自治区   0.982744  0.994572  0.988220
# 福建省       0.987677  0.991748  0.995865
# 陕西省       0.988071  0.999503  0.988325
# 山西省       0.994686  1.006249  0.988255
# 重庆市       0.995015  1.012453  0.983257
# 甘肃省       0.995988  1.025541  0.971482
# 湖南省       0.997145  1.001934  0.995359
# 安徽省       0.998662  1.004559  0.994136
# 贵州省       1.000015  1.022125  0.978503
# 湖北省       1.002159  1.003449  0.998686
# 浙江省       1.006645  0.995991  1.011204
# 天津市       1.013782  1.034002  0.980022
# 四川省       1.027041  1.019595  1.006972
# 吉林省       1.027661  1.046981  0.981475
# 黑龙江省      1.042133  1.058846  0.984422
# 河南省       1.062695  1.039367  1.022400
# 上海市            NaN  1.000000       NaN
# 北京市            NaN  1.000000       NaN
# 宁夏回族自治区        NaN  1.000000       NaN
# 广东省            NaN  1.000000       NaN
# 江苏省            NaN  1.000000       NaN
# 海南省            NaN  1.000000       NaN
# 青海省            NaN  1.000000       NaN

# %%
xtick2 = tuple(MQ_mean_cou.index)
xtick2
# Out:
# ('内蒙古自治区',
#  '山东省',
#  '云南省',
#  '河北省',
#  '辽宁省',
#  '江西省',
#  '新疆维吾尔自治区',
#  '广西壮族自治区',
#  '福建省',
#  '陕西省',
#  '山西省',
#  '重庆市',
#  '甘肃省',
#  '湖南省',
#  '安徽省',
#  '贵州省',
#  '湖北省',
#  '浙江省',
#  '天津市',
#  '四川省',
#  '吉林省',
#  '黑龙江省',
#  '河南省',
#  '上海市',
#  '北京市',
#  '宁夏回族自治区',
#  '广东省',
#  '江苏省',
#  '海南省',
#  '青海省')

# %%
fig, ax = plt.subplots() # 创建图形网格


ax.spines['top'].set_visible(False) # 使上边框不可见
ax.spines['right'].set_visible(False)
# ax2.spines['right'].set_visible(False)

################################ 绘图 #################################
if kind=="province":
   n_groups = 30 # 样本的数目（ref，mut1-3）
else:
   n_groups = 33  

index = np.arange(n_groups) # 转换为列表
bar_width = 0.5 # 设置柱子的宽度
# opacity = 0.8 # 设置柱子的透明度
error_config = {'ecolor': 'black','capsize' :2} # 设置误差线为黑色，宽度为2



# 画第一个样本的柱子
rects1 = ax.bar(index-bar_width/1.5, MQ_mean_cou,
                bar_width/2,
                color='darkblue',alpha = 0.8,
                 error_kw=error_config,
              edgecolor = 'white',label='MQ'
              )
rects2 = ax.bar(index , MEFFCH_mean_cou,
                bar_width/2,
                color='olivedrab',alpha = 0.8,
                 error_kw=error_config,
              edgecolor = 'white',label='MEFFCH'
              )

rects3 = ax.bar(index+bar_width/1.5, MTECHCH_mean_cou,
                bar_width/2,
                color='orange',alpha = 0.8,
                 error_kw=error_config,
              edgecolor = 'white',label='MTECHCH'
              )
###########################################333

# ax.set_xlabel('Hours in 4 ℃')
ax.set_ylabel( r'$\mathregular{能源效率}$')
#  r'$Difficulty of reducing emissions \gamma$' 
# ax.set_title('Creat by python')
ax.set_xticks(index )
ax.set_xticklabels(xtick2)
# ax2.set_xlabel('Relative gene expression')
# ax.spines["bottom"].set_position(("data",0))
plt.legend(loc='upper left')#borderaxespad=10,loc='upper right', fontsize='x-large'mode='expand'

plt.xticks(rotation=80)    # x 轴刻度添加80度旋转
# ax.legend(frameon=False,loc='best',ncol = 1)
if kind=="province":
   plt.savefig("chap42分省份能源效率.png", dpi=900, bbox_inches = 'tight')
else:
   plt.savefig("chap42分国家能源效率.png", dpi=900, bbox_inches = 'tight')

plt.show()
# Out:
# <div id='1662fd6c-ad5d-42b4-a544-58f9886f5010'></div>
