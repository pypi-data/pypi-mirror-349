# %%
# import packages
from deabook import DEA
from deabook.constant import CET_ADDI, RTS_VRS1, RTS_CRS, OPT_LOCAL

import pandas as pd
# import all data (including the contextual varibale)

kind = "country" # "province" or "country"

if kind == "province":
    dmuname = '省份'
    data = pd.read_excel(r"../../data\china data.xlsx").query('year>2015').reset_index(drop=True)
    region = data[["省份","group"]]
else:
    dmuname = '国家'
    data = pd.read_excel(r"../../data\oecd data.xlsx").query('year>2015').reset_index(drop=True)


yearid = data[['year',dmuname]]
yearid
# Out:
#      year    国家
# 0    2016  澳大利亚
# 1    2017  澳大利亚
# 2    2018  澳大利亚
# 3    2019  澳大利亚
# 4    2016   奥地利
# ..    ...   ...
# 127  2019   土耳其
# 128  2016    美国
# 129  2017    美国
# 130  2018    美国
# 131  2019    美国
#
# [132 rows x 2 columns]

# %%
data
# Out:
#      year    国家             K             Y           L           E  \
# 0    2016  澳大利亚  5.956383e+09  1.342079e+09   12.071554    6.009312
# 1    2017  澳大利亚  6.090384e+09  1.381660e+09   12.324088    6.200201
# 2    2018  澳大利亚  6.214957e+09  1.411518e+09   12.619437    6.161212
# 3    2019  澳大利亚  6.325938e+09  1.407497e+09   12.863174    6.123273
# 4    2016   奥地利  2.642944e+09  4.272328e+08    4.321229    1.461469
# ..    ...   ...           ...           ...         ...         ...
# 127  2019   土耳其  1.141520e+10  2.506658e+09   28.087334    6.609000
# 128  2016    美国  6.408426e+10  1.855046e+10  152.396957   97.383603
# 129  2017    美国  6.502516e+10  1.898318e+10  154.672318   97.659855
# 130  2018    美国  6.605931e+10  1.955201e+10  156.675903  101.234876
# 131  2019    美国  6.708090e+10  1.997456e+10  158.299591  100.470646
#
#           coal        gas  petroleum  nuclear_renewable        CO2
# 0     1.851000   1.561519   2.269023           0.327769   415.9452
# 1     1.834908   1.632484   2.370096           0.362713   414.7512
# 2     1.763525   1.586028   2.416194           0.395464   416.0012
# 3     1.710430   1.555931   2.403160           0.453751   414.5168
# 4     0.085731   0.316651   0.549274           0.509813    67.2155
# ..         ...        ...        ...                ...        ...
# 127   1.791918   1.619161   2.001988           1.195934   399.3449
# 128  14.225905  28.400352  37.194181          18.837677  5248.0239
# 129  13.837465  28.055093  37.522871          19.560595  5207.7513
# 130  13.251532  31.153422  38.354617          19.812072  5375.4906
# 131  11.315595  32.252007  38.329386          19.924565  5255.8162
#
# [132 rows x 11 columns]

# %%
yearid[dmuname].unique()
# Out:
# array(['澳大利亚', '奥地利', '比利时', '加拿大', '瑞士', '智利', '捷克', '德国', '丹麦', '西班牙',
#        '爱沙尼亚', '芬兰', '法国', '英国', '希腊', '匈牙利', '爱尔兰', '以色列', '意大利', '日本',
#        '韩国', '卢森', '墨西哥', '荷兰', '挪威', '新西兰', '波兰', '葡萄牙', '斯洛伐克', '斯洛文尼亚',
#        '瑞典', '土耳其', '美国'], dtype=object)

# %%
data[['Y','K','L','E','CO2']].describe().T
# Out:
#      count          mean           std           min           25%  \
# Y    132.0  1.702201e+09  3.350115e+09  3.594912e+07  2.855821e+08
# K    132.0  7.839578e+09  1.214657e+10  1.890386e+08  1.465476e+09
# L    132.0  1.834588e+01  2.928087e+01  4.141721e-01  2.896005e+00
# E    132.0  7.293261e+00  1.700883e+01  8.817377e-02  1.043768e+00
# CO2  132.0  3.777334e+02  9.074274e+02  9.092700e+00  4.180577e+01
#
#               50%           75%           max
# Y    4.895265e+08  2.070796e+09  1.997456e+10
# K    2.747511e+09  1.096015e+10  6.708090e+10
# L    4.998875e+00  2.546251e+01  1.582996e+02
# E    1.916515e+00  6.796940e+00  1.012349e+02
# CO2  8.440065e+01  3.905082e+02  5.375491e+03

# %%
data[['Y','K','L','E','CO2']].describe().T.to_markdown("table4.1.md")

# %%
ssss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ssss
#
# NameError: name 'ssss' is not defined

# %% [markdown]
# ## DEA

# %%
# define and solve the test_DEAt model
def DEA_CRS():

    model = DEA.DEA2(data,sent = "K L E =Y",   gy=[0], gx=[0,0,1], rts=RTS_CRS,  baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res
DEA_CRS = DEA_CRS()
DEA_CRS
# Out:
# Optimizing locally.
#     optimization_status       rho        te
# 0                    ok  0.322995  0.322995
# 1                    ok  0.322284  0.322284
# 2                    ok  0.331332  0.331332
# 3                    ok  0.332435  0.332435
# 4                    ok  0.422783  0.422783
# ..                  ...       ...       ...
# 127                  ok  0.548533  0.548533
# 128                  ok  0.380678  0.380678
# 129                  ok  0.399037  0.399037
# 130                  ok  0.413327  0.413327
# 131                  ok  0.433010  0.433010
#
# [132 rows x 3 columns]

# %%
def DEA_VRS():

    model = DEA.DEA2(data,sent = "K L E =Y", gy=[0], gx=[0,0,1],   baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res

DEA_VRS = DEA_VRS()
DEA_VRS
# Out:
# Optimizing locally.
#     optimization_status       rho        te
# 0                    ok  0.547721  0.547721
# 1                    ok  0.565104  0.565104
# 2                    ok  0.587107  0.587107
# 3                    ok  0.555465  0.555465
# 4                    ok  0.424521  0.424521
# ..                  ...       ...       ...
# 127                  ok  0.952187  0.952187
# 128                  ok  0.949870  0.949870
# 129                  ok  0.971977  0.971977
# 130                  ok  0.969095  0.969095
# 131                  ok  1.000000  1.000000
#
# [132 rows x 3 columns]

# %%
DEA_CRS = DEA_CRS.drop(columns = ['optimization_status','beta'])

DEA_VRS = DEA_VRS.drop(columns = ['optimization_status','beta'])


DEA_CRS =  DEA_CRS.rename(columns={'te':'PEO_CRS'})
DEA_VRS =  DEA_VRS.rename(columns={'te':'PEO_VRS'})


DEA_CRS2 = pd.concat([DEA_CRS,yearid],axis=1)
DEA_VRS2 = pd.concat([DEA_VRS,yearid],axis=1)

# %%
DEA_CRS2.query('year==2017').sort_values('PEO_CRS')
# Out:
#       PEO_CRS  year        省份
# 29   0.109438  2017   宁夏回族自治区
# 113  0.121411  2017       青海省
# 9    0.122712  2017    内蒙古自治区
# 53   0.146750  2017  新疆维吾尔自治区
# 89   0.211758  2017       甘肃省
# 97   0.215047  2017       贵州省
# 41   0.220487  2017       山西省
# 65   0.231751  2017       河北省
# 101  0.253018  2017       辽宁省
# 117  0.294503  2017      黑龙江省
# 25   0.303338  2017       天津市
# 5    0.317116  2017       云南省
# 105  0.336636  2017       重庆市
# 21   0.339277  2017       四川省
# 109  0.342899  2017       陕西省
# 61   0.344078  2017       江西省
# 49   0.345424  2017   广西壮族自治区
# 81   0.367053  2017       湖北省
# 17   0.368341  2017       吉林省
# 33   0.371303  2017       安徽省
# 69   0.376419  2017       河南省
# 85   0.376898  2017       湖南省
# 37   0.386793  2017       山东省
# 77   0.394635  2017       海南省
# 93   0.456344  2017       福建省
# 57   0.464044  2017       江苏省
# 73   0.551708  2017       浙江省
# 1    0.572235  2017       上海市
# 45   0.572992  2017       广东省
# 13   0.995989  2017       北京市

# %%
DEA_VRS2.query('year==2017').sort_values('PEO_VRS')
# Out:
#       PEO_VRS  year        省份
# 9    0.179405  2017    内蒙古自治区
# 53   0.213190  2017  新疆维吾尔自治区
md")

# %%
SSS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 SSS
#
# NameError: name 'SSS' is not defined

# %% [markdown]
# ## DDF

# %%
from pytedea import DDFt
from pytedea.constant import CET_ADDI, ORIENT_IO, ORIENT_OO, RTS_VRS, RTS_CRS, OPT_DEFAULT, OPT_LOCAL,\
            EMF_SAME, EMF_DIFFERENT

# %%
def DDF_CRS():

    model = DDFt.DDFt(data,sent = "K L E CO2=Y",  gy=[0], gx=[0,0,-1,0],rts=RTS_CRS, baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res

DDF_CRS=DDF_CRS()
DDF_CRS
# Out:
#      optimization_status          beta
# 0                    1.0  7.990619e-16
# 1                    1.0  0.000000e+00
# 2                    1.0  3.953763e-01
# 3                    1.0  4.225225e-01
# 4                    1.0  6.787623e-01
# ..                   ...           ...
# 115                  1.0  8.771194e-01
# 116                  1.0  7.021534e-01
# 117                  1.0  7.054967e-01
# 118                  1.0  6.402979e-01
# 119                  1.0  6.721113e-01
#
# [120 rows x 2 columns]

# %%
def DDF_VRS():

    model = DDFt.DDFt(data,sent = "K L E CO2=Y",  gy=[0], gx=[0,0,-1,0],rts=RTS_VRS, baseindex=None,refindex=None)
    res = model.optimize(solver="mosek")
    # print(model.info(1))
    return res

DDF_VRS=DDF_VRS()
DDF_VRS
# Out:
#      optimization_status          beta
# 0                    1.0  0.000000e+00
# 1                    1.0  0.000000e+00
# 2                    1.0  1.521410e-16
# 3                    1.0  7.902117e-02
# 4                    1.0  6.060895e-01
# ..                   ...           ...
# 115                  1.0  0.000000e+00
# 116                  1.0  6.233182e-01
# 117                  1.0  6.240601e-01
# 118                  1.0  5.405415e-01
# 119                  1.0  5.834303e-01
#
# [120 rows x 2 columns]

# %%
DDF_CRS['EO_CRS'] = (1- DDF_CRS['beta'])
DDF_VRS['EO_VRS'] = (1- DDF_VRS['beta'])

DDF_CRS = DDF_CRS.drop(columns = ['optimization_status','beta'])
DDF_VRS = DDF_VRS.drop(columns = ['optimization_status','beta'])



DDF_CRS2 = pd.concat([DDF_CRS,yearid],axis=1)
DDF_VRS2 = pd.concat([DDF_VRS,yearid],axis=1)

# %%
DDF_CRS2
# Out:
#        EO_CRS  year    省份
# 0    1.000000  2016   上海市
# 1    1.000000  2017   上海市
# 2    0.604624  2018   上海市
# 3    0.577478  2019   上海市
# 4    0.321238  2016   云南省
# ..        ...   ...   ...
# 115  0.122881  2019   青海省
# 116  0.297847  2016  黑龙江省
# 117  0.294503  2017  黑龙江省
# 118  0.359702  2018  黑龙江省
# 119  0.327889  2019  黑龙江省
#
# [120 rows x 3 columns]

# %%
DDF_CRS3 = DDF_CRS2.pivot_table(
    values=['EO_CRS',],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
DDF_VRS3 = DDF_VRS2.pivot_table(
    values=['EO_VRS',],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
DDF_CRS3.to_markdown("DDF_CRS.md")
DDF_VRS3.to_markdown("DDF_VRS.md")

# %%
SSS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 SSS
#
# NameError: name 'SSS' is not defined

# %% [markdown]
# ## figure

# %%
ddf_mean_year = DDF_VRS3['EO_VRS'].mean()

xtick2 = tuple(ddf_mean_year.index)

# %%
ddf_mean_year.mean()
# Out:
# 0.5293658003445811

# %%
ddf_mean_year
# Out:
# year
# 2016    0.525358
# 2017    0.534664
# 2018    0.535468
# 2019    0.521973
# dtype: float64

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib notebook
# plt.figure(figsize=(1,1))
params = {
    'figure.figsize': '8, 4'
}
# plt.rcParams.update(params)
# plt.rc('font',family='Times New Roman')
from matplotlib import rcParams
rcParams['font.family'] = 'SimHei'


import numpy as np

# %%
fig, ax = plt.subplots() # 创建图形网格


ax.spines['top'].set_visible(False) # 使上边框不可见
ax.spines['right'].set_visible(False)
# ax2.spines['right'].set_visible(False)

################################ 绘图 #################################

n_groups = 4 # 样本的数目（ref，mut1-3）
index = np.arange(n_groups) # 转换为列表
bar_width = 0.5 # 设置柱子的宽度
# opacity = 0.8 # 设置柱子的透明度
error_config = {'ecolor': 'black','capsize' :2} # 设置误差线为黑色，宽度为2



# 画第一个样本的柱子
rects1 = ax.plot(index, ddf_mean_year,
                color='darkblue',alpha = 0.8,linestyle = "dashed",marker = "s",label='DDF_VRS'
            #      error_kw=error_config,
            #   edgecolor = 'white'
              )

###########################################333

# ax.set_xlabel('Hours in 4 ℃')
ax.set_ylabel( r'$\mathregular{能源效率}$')
#  r'$Difficulty of reducing emissions \gamma$' 
# ax.set_title('Creat by python')
ax.set_xticks(index )
ax.set_xticklabels(xtick2)
# ax2.set_xlabel('Relative gene expression')
# ax.spines["bottom"].set_position(("data",0))
plt.legend()#borderaxespad=10,loc='upper right', fontsize='x-large'mode='expand'

plt.xticks(rotation=80)    # x 轴刻度添加80度旋转
# ax.legend(frameon=False,loc='best',ncol = 1)
if kind=="province":
   plt.savefig("chap41分年份能源效率-省.png", dpi=900, bbox_inches = 'tight')
else:
   plt.savefig("chap41分年份能源效率-国.png", dpi=900, bbox_inches = 'tight')
plt.show()
# Out:
# <div id='727d17d0-30ce-41ab-a9c7-458e6adfe3ff'></div>

# %%
ddf_mean_cou = DDF_VRS3['EO_VRS'].mean(axis=1) .sort_values()

# %%
ddf_mean_cou
# Out:
# 省份
# 内蒙古自治区      0.163240
# 新疆维吾尔自治区    0.214346
# 河北省         0.243310
# 山西省         0.254045
# 辽宁省         0.260057
# 贵州省         0.319397
# 四川省         0.347403
# 云南省         0.373178
# 湖北省         0.377805
# 甘肃省         0.382193
# 陕西省         0.395205
# 湖南省         0.398789
# 安徽省         0.399029
# 黑龙江省        0.407162
# 广西壮族自治区     0.410948
# 江西省         0.418969
# 天津市         0.421552
# 重庆市         0.451696
# 河南省         0.454317
# 福建省         0.469928
# 吉林省         0.505941
# 山东省         0.575586
# 浙江省         0.796737
# 江苏省         0.941189
# 海南省         0.956602
# 宁夏回族自治区     0.969549
# 上海市         0.980245
# 广东省         0.992556
# 青海省         1.000000
# 北京市         1.000000
# dtype: float64

# %%
xtick2 = tuple(ddf_mean_cou.index)
xtick2
# Out:
# ('内蒙古自治区',
#  '新疆维吾尔自治区',
#  '河北省',
#  '山西省',
#  '辽宁省',
#  '贵州省',
#  '四川省',
#  '云南省',
#  '湖北省',
#  '甘肃省',
#  '陕西省',
#  '湖南省',
#  '安徽省',
#  '黑龙江省',
#  '广西壮族自治区',
#  '江西省',
#  '天津市',
#  '重庆市',
#  '河南省',
#  '福建省',
#  '吉林省',
#  '山东省',
#  '浙江省',
#  '江苏省',
#  '海南省',
#  '宁夏回族自治区',
#  '上海市',
#  '广东省',
#  '青海省',
#  '北京市')

# %%
fig, ax = plt.subplots() # 创建图形网格


ax.spines['top'].set_visible(False) # 使上边框不可见
ax.spines['right'].set_visible(False)
# ax2.spines['right'].set_visible(False)

################################ 绘图 #################################
if kind=="province":
   n_groups = 30 # 样本的数目（ref，mut1-3）
else:
   n_groups = 33  

index = np.arange(n_groups) # 转换为列表
bar_width = 0.5 # 设置柱子的宽度
# opacity = 0.8 # 设置柱子的透明度
error_config = {'ecolor': 'black','capsize' :2} # 设置误差线为黑色，宽度为2



# 画第一个样本的柱子

rects2 = ax.bar(index , ddf_mean_cou,
                bar_width/2,
                color='olivedrab',alpha = 0.8,
                 error_kw=error_config,
              edgecolor = 'white',label='DDF_VRS'
              )

###########################################333

# ax.set_xlabel('Hours in 4 ℃')
ax.set_ylabel( r'$\mathregular{能源效率}$')
#  r'$Difficulty of reducing emissions \gamma$' 
# ax.set_title('Creat by python')
ax.set_xticks(index )
ax.set_xticklabels(xtick2)
# ax2.set_xlabel('Relative gene expression')
# ax.spines["bottom"].set_position(("data",0))
plt.legend(loc='upper left')#borderaxespad=10,loc='upper right', fontsize='x-large'mode='expand'

plt.xticks(rotation=80)    # x 轴刻度添加80度旋转
# ax.legend(frameon=False,loc='best',ncol = 1)
if kind=="province":
   plt.savefig("chap41分省份能源效率.png", dpi=900, bbox_inches = 'tight')
else:
   plt.savefig("chap41分国家能源效率.png", dpi=900, bbox_inches = 'tight')

plt.show()
# Out:
# <div id='5ca1f2cd-f13c-4bbd-ab62-9482e5dd7a27'></div>
