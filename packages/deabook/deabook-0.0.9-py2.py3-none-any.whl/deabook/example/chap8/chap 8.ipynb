# %%
# import packages
import pandas as pd


# import all data (including the contextual varibale)
from pandas.api.types import CategoricalDtype
cat_size_order = CategoricalDtype(
    ['MQ', 'MEFFCH', 'MTECHCH'], 
    ordered=True
)



import pandas as pd
# import all data (including the contextual varibale)

kind = "province" # "province" or "country"

if kind == "province":
    dmuname = '省份'
    data = pd.read_excel(r"../../data\china data.xlsx").query('year>2015').reset_index(drop=True)
    region = data[["省份","group"]]
else:
    dmuname = '国家'
    data = pd.read_excel(r"../../data\oecd data.xlsx").query('year>2015').reset_index(drop=True)


yearid = data[['year',dmuname]]
yearid
# Out:
#      year    省份
# 0    2016   上海市
# 1    2017   上海市
# 2    2018   上海市
# 3    2019   上海市
# 4    2016   云南省
# ..    ...   ...
# 115  2019   青海省
# 116  2016  黑龙江省
# 117  2017  黑龙江省
# 118  2018  黑龙江省
# 119  2019  黑龙江省
#
# [120 rows x 2 columns]

# %%
data
# Out:
#        省份  year           Y             E        L             K         CO2  \
# 0     上海市  2016  902.794998  11286.777262  1365.24  4.085533e+06  188.140000
# 1     上海市  2017  929.498785  11423.298889  1372.65  4.238459e+06  190.480000
# 2     上海市  2018  951.911601  11072.057032  1375.66  5.790083e+06  190.641610
# 3     上海市  2019  947.300532  11536.380416  1376.20  6.373635e+06  192.912182
# 4     云南省  2016  427.550554   9360.041199  2855.00  4.787612e+06  180.050000
# ..    ...   ...         ...           ...      ...           ...         ...
# 115   青海省  2019   62.322152   3566.776509   330.20  1.164860e+06   51.752403
# 116  黑龙江省  2016  394.193978   9307.525536  1776.00  4.500560e+06  269.340000
# 117  黑龙江省  2017  384.949317   9192.427176  1699.00  4.867986e+06  268.660000
# 118  黑龙江省  2018  384.333468   7514.188572  1635.00  4.611428e+06  248.035933
# 119  黑龙江省  2019  389.627692   8356.804833  1551.00  4.770895e+06  278.211338
#
#     group
# 0       E
# 1       E
# 2       E
# 3       E
# 4       W
# ..    ...
# 115     W
# 116     C
# 117     C
# 118     C
# 119     C
#
# [120 rows x 8 columns]

# %%
yearid[dmuname].unique()
# Out:
# array(['上海市', '云南省', '内蒙古自治区', '北京市', '吉林省', '四川省', '天津市', '宁夏回族自治区',
#        '安徽省', '山东省', '山西省', '广东省', '广西壮族自治区', '新疆维吾尔自治区', '江苏省', '江西省',
#        '河北省', '河南省', '浙江省', '海南省', '湖北省', '湖南省', '甘肃省', '福建省', '贵州省',
#        '辽宁省', '重庆市', '陕西省', '青海省', '黑龙江省'], dtype=object)

# %%
ssss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ssss
#
# NameError: name 'ssss' is not defined

# %% [markdown]
# ## CNLSSDb

# %%
from deabook import CNLSSDFDDFweak,StoNED
from deabook.constant import FUN_PROD, OPT_LOCAL,RTS_VRS1 ,RTS_CRS,CET_ADDI, CET_MULT,RED_QLE

# define and solve the test_DEAt model
def CNLSSDb_CRS():

    model = CNLSSDFDDFweak.CNLSSDweak(data,sent = "K L E=Y:CO2", \
                               gy=[0],gx=[0,0,0],gb=[1], \
                                cet=CET_MULT, rts=RTS_CRS, fun=FUN_PROD, \
                              )
    # model.optimize( email= '1019753743@qq.com',)
    model.optimize(solver="knitro",)

    rd = StoNED.StoNED(model)
    res=rd.get_technical_efficiency(RED_QLE)
    return res
CNLSSDb_CRS = CNLSSDb_CRS()
CNLSSDb_CRS
# Out:
# Optimizing locally.
# WARNING: Failed to create solver with name 'knitro': Failed to set executable
# for solver asl. File with name=knitro either does not exist or it is not
# executable. To skip this validation, call set_executable with validate=False.
# Traceback (most recent call last):
#   File "d:\ProgramData\anaconda3\envs\deabook\Lib\site-packages\pyomo\opt\base\solvers.py", line 162, in __call__
#     opt = self._cls[_implicit_solvers[mode]](**kwds)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\ProgramData\anaconda3\envs\deabook\Lib\site-packages\pyomo\solvers\plugins\solvers\ASL.py", line 46, in __init__
#     SystemCallSolver.__init__(self, **kwds)
#   File "d:\ProgramData\anaconda3\envs\deabook\Lib\site-packages\pyomo\opt\solver\shellcmd.py", line 66, in __init__
#     self.set_executable(name=executable, validate=validate)
#   File "d:\ProgramData\anaconda3\envs\deabook\Lib\site-packages\pyomo\opt\solver\shellcmd.py", line 115, in set_executable
#     raise ValueError(
# ValueError: Failed to set executable for solver asl. File with name=knitro either does not exist or it is not executable. To skip this validation, call set_executable with validate=False.
# Estimating the multiplicative model locally with knitro solver.
# Estimating the multiplicative model locally with knitro solver.
# Artelys Knitro 14.2.0: soltype=1
#
# =======================================
#           Commercial License
#          Artelys Knitro 14.2.0
# =======================================
#
# Knitro using up to 8 threads.
# No start point provided -- Knitro computing one.
#
# Knitro presolve eliminated 120 variables and 120 constraints.
#
# concurrent_evals         0
# datacheck                0
# findiff_numthreads       1
# hessian_no_f             1
# hessopt                  1
# soltype                  1
# Knitro fixing 120 variables eliminated from the presolve.
#
# Problem Characteristics                                 (   Presolved)
# -----------------------
# Objective goal:  Minimize
# Objective type:  quadratic
# Number of variables:                                840 (         720)
#     bounded below only:                             720 (         600)
#     bounded above only:                               0 (           0)
#     bounded below and above:                          0 (           0)
#     fixed:                                            0 (           0)
#     free:                                           120 (         120)
# Number of constraints:                            14640 (       14520)
#     linear equalities:                              240 (         120)
#     quadratic equalities:                             0 (           0)
#     gen. nonlinear equalities:                      120 (         120)
#     linear one-sided inequalities:                14280 (       14280)
#     quadratic one-sided inequalities:                 0 (           0)
#     gen. nonlinear one-sided inequalities:            0 (           0)
#     linear two-sided inequalities:                    0 (           0)
#     quadratic two-sided inequalities:                 0 (           0)
#     gen. nonlinear two-sided inequalities:            0 (           0)
# Number of nonzeros in Jacobian:                   86760 (       72240)
# Number of nonzeros in Hessian:                      240 (         240)
#
# Knitro using the Interior-Point/Barrier Direct algorithm.
#
#   Iter      Objective      FeasError   OptError    ||Step||    CGits
# --------  --------------  ----------  ----------  ----------  -------
#        0    3.716761e-11   3.559e+07
#       10    4.973374e+03   3.787e+06   1.489e+01   2.038e+03        0
#       20    3.833229e+03   1.964e+03   1.832e-02   1.083e+04        0
#       23    3.831684e+03   2.457e-04   2.307e-09   1.069e+00        0
#
# EXIT: Locally optimal solution found.
#
# NOTE: Knitro returning the best feasible iterate.
#
# Final Statistics
# ----------------
# Final objective value               =   3.83168361917538e+03
# Final feasibility error (abs / rel) =   2.46e-04 / 6.90e-12
# Final optimality error  (abs / rel) =   2.31e-09 / 1.69e-10
# # of iterations                     =         23
# # of CG iterations                  =          0
# # of function evaluations           =         27
# # of gradient evaluations           =         25
# # of Hessian evaluations            =         23
# Total program time (secs)           =       0.607 (     4.141 CPU time)
# Time spent in evaluations (secs)    =       0.002
#
# ===============================================================================
# array([0.10659141, 0.10791624, 0.10800774, 0.10929326, 0.10201102,
#        0.11019222, 0.1202379 , 0.10535484, 0.33387182, 0.36188177,
#        0.40952025, 0.44936686, 0.0506357 , 0.04816591, 0.05076751,
#        0.04997035, 0.11387221, 0.11555365, 0.11118146, 0.11537903,
#        0.17545358, 0.17527247, 0.16782396, 0.17849478, 0.08304811,
#        0.07984866, 0.08731366, 0.08979017, 0.07737398, 0.09921968,
#        0.10854414, 0.12033395, 0.20520557, 0.20984042, 0.22593132,
#        0.23106954, 0.47092765, 0.45590502, 0.50920526, 0.52862255,
#        0.25451052, 0.27629467, 0.30673735, 0.32070444, 0.29307611,
#        0.30712416, 0.32128301, 0.33163762, 0.11963547, 0.1249853 ,
#        0.13132724, 0.13975268, 0.20974422, 0.22854893, 0.2386929 ,
#        0.25778364, 0.40975819, 0.41672354, 0.43235436, 0.45516079,
#        0.12084132, 0.12689308, 0.13404244, 0.13725719, 0.42357783,
#        0.41084782, 0.51500938, 0.51610932, 0.29042824, 0.27992713,
#        0.27781565, 0.26081437, 0.21068363, 0.21639362, 0.22018249,
#        0.21598459, 0.02260083, 0.02391003, 0.02392911, 0.02442411,
#        0.17599692, 0.18382996, 0.18257141, 0.20090028, 0.16638641,
#        0.17542528, 0.17329185, 0.17593561, 0.08634374, 0.08527918,
#        0.09235171, 0.09319996, 0.12089227, 0.13050479, 0.14809573,
#        0.15752227, 0.1410565 , 0.14463965, 0.14330411, 0.14791099,
#        0.25860717, 0.27130989, 0.29496171, 0.3019805 , 0.08704022,
#        0.08931086, 0.09110795, 0.08853776, 0.15033409, 0.14838124,
#        0.15642707, 0.16780285, 0.03201362, 0.0301777 , 0.02945123,
#        0.02934607, 0.15255861, 0.15217371, 0.14049945, 0.15758003])

# %%
from deabook import CNLSSDFDDFweak,StoNED
from deabook.constant import FUN_PROD, OPT_LOCAL,RTS_VRS1,RTS_VRS2 ,RTS_CRS,CET_ADDI, CET_MULT,RED_QLE

# define and solve the test_DEAt model
def CNLSSDb_VRS_SAME():

    model = CNLSSDFDDFweak.CNLSSDweak(data,sent = "K L E=Y:CO2", \
                               gy=[0],gx=[0,0,0],gb=[1], \
                                cet=CET_MULT, rts=RTS_VRS1, fun=FUN_PROD, \
                              )
    # model.optimize( email= '1019753743@qq.com',)
    model.optimize(solver="knitro",)

    rd = StoNED.StoNED(model)
    res=rd.get_technical_efficiency(RED_QLE)
    return res
CNLSSDb_VRS_SAME = CNLSSDb_VRS_SAME()
CNLSSDb_VRS_SAME
# Out:
# Optimizing locally.
# Estimating the multiplicative model locally with knitro solver.
# Artelys Knitro 14.2.0:
# =======================================
#           Commercial License
#          Artelys Knitro 14.2.0
# =======================================
#
# Knitro using up to 8 threads.
# No start point provided -- Knitro computing one.
#
# Knitro presolve eliminated 120 variables and 120 constraints.
#
# concurrent_evals         0
# datacheck                0
# findiff_numthreads       1
# hessian_no_f             1
# hessopt                  1
# Knitro fixing 120 variables eliminated from the presolve.
#
# Problem Characteristics                                 (   Presolved)
# -----------------------
# Objective goal:  Minimize
# Objective type:  quadratic
# Number of variables:                                960 (         840)
#     bounded below only:                             840 (         720)
#     bounded above only:                               0 (           0)
#     bounded below and above:                          0 (           0)
#     fixed:                                            0 (           0)
#     free:                                           120 (         120)
# Number of constraints:                            14640 (       14520)
#     linear equalities:                              240 (         120)
#     quadratic equalities:                             0 (           0)
#     gen. nonlinear equalities:                      120 (         120)
#     linear one-sided inequalities:                14280 (       14280)
#     quadratic one-sided inequalities:                 0 (           0)
#     gen. nonlinear one-sided inequalities:            0 (           0)
#     linear two-sided inequalities:                    0 (           0)
#     quadratic two-sided inequalities:                 0 (           0)
#     gen. nonlinear two-sided inequalities:            0 (           0)
# Number of nonzeros in Jacobian:                  101040 (       86520)
# Number of nonzeros in Hessian:                      240 (         240)
#
# Knitro using the Interior-Point/Barrier Direct algorithm.
#
#   Iter      Objective      FeasError   OptError    ||Step||    CGits
# --------  --------------  ----------  ----------  ----------  -------
#        0    3.716761e-11   3.559e+07
#       10    4.940711e+03   3.768e+06   1.484e+01   2.028e+03        0
#       20    3.833177e+03   1.922e+03   1.806e-02   1.074e+04        0
#       23    3.831684e+03   2.406e-04   2.274e-09   1.069e+00        0
#
# EXIT: Locally optimal solution found.
#
# Final Statistics
# ----------------
# Final objective value               =   3.83168361916883e+03
# Final feasibility error (abs / rel) =   2.41e-04 / 6.76e-12
# Final optimality error  (abs / rel) =   2.27e-09 / 1.66e-10
# # of iterations                     =         23
# # of CG iterations                  =          0
# # of function evaluations           =         27
# # of gradient evaluations           =         25
# # of Hessian evaluations            =         23
# Total program time (secs)           =       0.686 (     4.219 CPU time)
# Time spent in evaluations (secs)    =       0.001
#
# ===============================================================================
# array([0.10659145, 0.10791628, 0.10800778, 0.1092933 , 0.10201105,
#        0.11019225, 0.12023794, 0.10535488, 0.33387191, 0.36188186,
#        0.40952032, 0.44936685, 0.05063572, 0.04816593, 0.05076753,
#        0.04997037, 0.11387224, 0.11555369, 0.11118149, 0.11537907,
#        0.17545364, 0.17527252, 0.16782401, 0.17849483, 0.08304814,
#        0.07984869, 0.0873137 , 0.0897902 , 0.07737401, 0.09921972,
#        0.10854418, 0.12033399, 0.20520563, 0.20984049, 0.22593139,
#        0.23106961, 0.47092756, 0.45590499, 0.50920491, 0.52862199,
#        0.25451059, 0.27629475, 0.30673743, 0.32070452, 0.29307619,
#        0.30712425, 0.3212831 , 0.33163771, 0.11963551, 0.12498534,
#        0.13132728, 0.13975273, 0.20974428, 0.228549  , 0.23869297,
#        0.25778371, 0.40975826, 0.4167236 , 0.43235439, 0.45516076,
#        0.12084136, 0.12689312, 0.13404248, 0.13725723, 0.42357788,
#        0.41084788, 0.51500897, 0.5161089 , 0.29042832, 0.2799272 ,
#        0.27781572, 0.26081444, 0.21068369, 0.21639368, 0.22018255,
#        0.21598466, 0.02260084, 0.02391004, 0.02392912, 0.02442413,
#        0.17599698, 0.18383002, 0.18257147, 0.20090034, 0.16638646,
#        0.17542534, 0.1732919 , 0.17593566, 0.08634377, 0.08527921,
#        0.09235174, 0.09319999, 0.12089231, 0.13050483, 0.14809578,
#        0.15752232, 0.14105654, 0.1446397 , 0.14330416, 0.14791104,
#        0.25860724, 0.27130996, 0.29496179, 0.30198058, 0.08704026,
#        0.08931089, 0.09110798, 0.08853779, 0.15033413, 0.14838129,
#        0.15642712, 0.1678029 , 0.03201364, 0.03017771, 0.02945124,
#        0.02934609, 0.15255866, 0.15217376, 0.1404995 , 0.15758008])

# %%
from deabook import CNLSSDFDDFweak,StoNED
from deabook.constant import FUN_PROD, OPT_LOCAL,RTS_VRS1,RTS_VRS2 ,RTS_CRS,CET_ADDI, CET_MULT,RED_QLE

# define and solve the test_DEAt model
def CNLSSDb_VRS_DIFF():

    model = CNLSSDFDDFweak.CNLSSDweak(data,sent = "K L E=Y:CO2", \
                               gy=[0],gx=[0,0,0],gb=[1], \
                                cet=CET_MULT, rts=RTS_VRS2, fun=FUN_PROD, \
                              )
    # model.optimize( email= '1019753743@qq.com',)
    model.optimize(solver="knitro",)

    rd = StoNED.StoNED(model)
    res=rd.get_technical_efficiency(RED_QLE)
    return res
CNLSSDb_VRS_DIFF = CNLSSDb_VRS_DIFF()
CNLSSDb_VRS_DIFF
# Out:
# Optimizing locally.
# Estimating the multiplicative model locally with knitro solver.
# Artelys Knitro 14.2.0:
# =======================================
#           Commercial License
#          Artelys Knitro 14.2.0
# =======================================
#
# Knitro using up to 8 threads.
# No start point provided -- Knitro computing one.
#
# Knitro presolve eliminated 120 variables and 120 constraints.
#
# concurrent_evals         0
# datacheck                0
# findiff_numthreads       1
# hessian_no_f             1
# hessopt                  1
# Knitro fixing 120 variables eliminated from the presolve.
#
# Problem Characteristics                                 (   Presolved)
# -----------------------
# Objective goal:  Minimize
# Objective type:  quadratic
# Number of variables:                                960 (         840)
#     bounded below only:                             720 (         600)
#     bounded above only:                               0 (           0)
#     bounded below and above:                          0 (           0)
#     fixed:                                            0 (           0)
#     free:                                           240 (         240)
# Number of constraints:                            29040 (       28920)
#     linear equalities:                              240 (         120)
#     quadratic equalities:                             0 (           0)
#     gen. nonlinear equalities:                      120 (         120)
#     linear one-sided inequalities:                28680 (       28680)
#     quadratic one-sided inequalities:                 0 (           0)
#     gen. nonlinear one-sided inequalities:            0 (           0)
#     linear two-sided inequalities:                    0 (           0)
#     quadratic two-sided inequalities:                 0 (           0)
#     gen. nonlinear two-sided inequalities:            0 (           0)
# Number of nonzeros in Jacobian:                  158760 (      144240)
# Number of nonzeros in Hessian:                      240 (         240)
#
# Knitro using the Interior-Point/Barrier Direct algorithm.
#
#   Iter      Objective      FeasError   OptError    ||Step||    CGits
# --------  --------------  ----------  ----------  ----------  -------
#        0    3.716761e-11   3.671e+07
#       10    1.843480e+03   1.813e+07   8.713e+00   1.936e+06        0
#       20    3.262858e+03   9.037e+06   1.175e+01   1.768e+06        0
#       30    4.086813e+03   3.220e+06   1.352e+01   4.777e+06        0
#       40    4.163620e+03   7.524e+05   1.396e+01   1.591e+07        0
#       50    3.831684e+03   7.712e-05   2.036e-09   7.037e-06        1
#
# EXIT: Locally optimal solution found.
#
# Final Statistics
# ----------------
# Final objective value               =   3.83168361897921e+03
# Final feasibility error (abs / rel) =   7.71e-05 / 2.10e-12
# Final optimality error  (abs / rel) =   2.04e-09 / 1.49e-10
# # of iterations                     =         50
# # of CG iterations                  =          1
# # of function evaluations           =         60
# # of gradient evaluations           =         52
# # of Hessian evaluations            =         50
# Total program time (secs)           =       4.429 (    24.219 CPU time)
# Time spent in evaluations (secs)    =       0.005
#
# ===============================================================================
# array([0.10659145, 0.10791629, 0.10800779, 0.1092933 , 0.10201106,
#        0.11019226, 0.12023794, 0.10535488, 0.33387193, 0.36188187,
#        0.40952033, 0.44936685, 0.05063572, 0.04816593, 0.05076754,
#        0.04997038, 0.11387225, 0.1155537 , 0.1111815 , 0.11537908,
#        0.17545365, 0.17527253, 0.16782402, 0.17849484, 0.08304814,
#        0.07984869, 0.0873137 , 0.08979021, 0.07737402, 0.09921972,
#        0.10854419, 0.120334  , 0.20520564, 0.2098405 , 0.2259314 ,
#        0.23106962, 0.47092754, 0.45590498, 0.50920484, 0.52862188,
#        0.25451061, 0.27629476, 0.30673745, 0.32070454, 0.2930762 ,
#        0.30712426, 0.32128311, 0.33163772, 0.11963552, 0.12498534,
#        0.13132729, 0.13975274, 0.20974429, 0.22854901, 0.23869298,
#        0.25778373, 0.40975827, 0.41672361, 0.4323544 , 0.45516076,
#        0.12084137, 0.12689313, 0.13404249, 0.13725724, 0.42357789,
#        0.41084789, 0.51500889, 0.51610882, 0.29042834, 0.27992722,
#        0.27781574, 0.26081446, 0.21068371, 0.21639369, 0.22018257,
#        0.21598467, 0.02260084, 0.02391005, 0.02392912, 0.02442413,
#        0.17599699, 0.18383003, 0.18257148, 0.20090035, 0.16638647,
#        0.17542535, 0.17329191, 0.17593567, 0.08634377, 0.08527921,
#        0.09235175, 0.0932    , 0.12089232, 0.13050484, 0.14809579,
#        0.15752233, 0.14105655, 0.14463971, 0.14330417, 0.14791105,
#        0.25860726, 0.27130998, 0.29496181, 0.3019806 , 0.08704026,
#        0.0893109 , 0.09110799, 0.0885378 , 0.15033414, 0.1483813 ,
#        0.15642713, 0.16780291, 0.03201364, 0.03017772, 0.02945125,
#        0.02934609, 0.15255867, 0.15217376, 0.14049951, 0.15758009])

# %%
CNLSSDb_CRS2 = pd.DataFrame(CNLSSDb_CRS,columns=['TE'])
CNLSSDb_CRS2 = pd.concat([data,CNLSSDb_CRS2], axis=1)
CNLSSDb_VRS_SAME2 = pd.DataFrame(CNLSSDb_VRS_SAME,columns=['TE']) 
CNLSSDb_VRS_SAME2 = pd.concat([data,CNLSSDb_VRS_SAME2], axis=1)

CNLSSDb_VRS_DIFF2 = pd.DataFrame(CNLSSDb_VRS_DIFF,columns=['TE']) 
CNLSSDb_VRS_DIFF2 = pd.concat([data,CNLSSDb_VRS_DIFF2], axis=1)

# %%
CNLSSDb_CRS2
# Out:
#        省份  year           Y             E        L             K         CO2  \
# 0     上海市  2016  902.794998  11286.777262  1365.24  4.085533e+06  188.140000
# 1     上海市  2017  929.498785  11423.298889  1372.65  4.238459e+06  190.480000
# 2     上海市  2018  951.911601  11072.057032  1375.66  5.790083e+06  190.641610
# 3     上海市  2019  947.300532  11536.380416  1376.20  6.373635e+06  192.912182
# 4     云南省  2016  427.550554   9360.041199  2855.00  4.787612e+06  180.050000
# ..    ...   ...         ...           ...      ...           ...         ...
# 115   青海省  2019   62.322152   3566.776509   330.20  1.164860e+06   51.752403
# 116  黑龙江省  2016  394.193978   9307.525536  1776.00  4.500560e+06  269.340000
# 117  黑龙江省  2017  384.949317   9192.427176  1699.00  4.867986e+06  268.660000
# 118  黑龙江省  2018  384.333468   7514.188572  1635.00  4.611428e+06  248.035933
# 119  黑龙江省  2019  389.627692   8356.804833  1551.00  4.770895e+06  278.211338
#
#     group        TE
# 0       E  0.106591
# 1       E  0.107916
# 2       E  0.108008
# 3       E  0.109293
# 4       W  0.102011
# ..    ...       ...
# 115     W  0.029346
# 116     C  0.152559
# 117     C  0.152174
# 118     C  0.140499
# 119     C  0.157580
#
# [120 rows x 9 columns]

# %%
CNLSSDb_VRS_SAME2
# Out:
#        省份  year           Y             E        L             K         CO2  \
# 0     上海市  2016  902.794998  11286.777262  1365.24  4.085533e+06  188.140000
# 1     上海市  2017  929.498785  11423.298889  1372.65  4.238459e+06  190.480000
# 2     上海市  2018  951.911601  11072.057032  1375.66  5.790083e+06  190.641610
# 3     上海市  2019  947.300532  11536.380416  1376.20  6.373635e+06  192.912182
# 4     云南省  2016  427.550554   9360.041199  2855.00  4.787612e+06  180.050000
# ..    ...   ...         ...           ...      ...           ...         ...
# 115   青海省  2019   62.322152   3566.776509   330.20  1.164860e+06   51.752403
# 116  黑龙江省  2016  394.193978   9307.525536  1776.00  4.500560e+06  269.340000
# 117  黑龙江省  2017  384.949317   9192.427176  1699.00  4.867986e+06  268.660000
# 118  黑龙江省  2018  384.333468   7514.188572  1635.00  4.611428e+06  248.035933
# 119  黑龙江省  2019  389.627692   8356.804833  1551.00  4.770895e+06  278.211338
#
#     group        TE
# 0       E  0.106591
# 1       E  0.107916
# 2       E  0.108008
# 3       E  0.109293
# 4       W  0.102011
# ..    ...       ...
# 115     W  0.029346
# 116     C  0.152559
# 117     C  0.152174
# 118     C  0.140499
# 119     C  0.157580
#
# [120 rows x 9 columns]

# %%
CNLSSDb_VRS_DIFF2
# Out:
#        省份  year           Y             E        L             K         CO2  \
# 0     上海市  2016  902.794998  11286.777262  1365.24  4.085533e+06  188.140000
# 1     上海市  2017  929.498785  11423.298889  1372.65  4.238459e+06  190.480000
# 2     上海市  2018  951.911601  11072.057032  1375.66  5.790083e+06  190.641610
# 3     上海市  2019  947.300532  11536.380416  1376.20  6.373635e+06  192.912182
# 4     云南省  2016  427.550554   9360.041199  2855.00  4.787612e+06  180.050000
# ..    ...   ...         ...           ...      ...           ...         ...
# 115   青海省  2019   62.322152   3566.776509   330.20  1.164860e+06   51.752403
# 116  黑龙江省  2016  394.193978   9307.525536  1776.00  4.500560e+06  269.340000
# 117  黑龙江省  2017  384.949317   9192.427176  1699.00  4.867986e+06  268.660000
# 118  黑龙江省  2018  384.333468   7514.188572  1635.00  4.611428e+06  248.035933
# 119  黑龙江省  2019  389.627692   8356.804833  1551.00  4.770895e+06  278.211338
#
#     group        TE
# 0       E  0.106591
# 1       E  0.107916
# 2       E  0.108008
# 3       E  0.109293
# 4       W  0.102011
# ..    ...       ...
# 115     W  0.029346
# 116     C  0.152559
# 117     C  0.152174
# 118     C  0.140500
# 119     C  0.157580
#
# [120 rows x 9 columns]

# %%
CNLSSDb_CRS3 = CNLSSDb_CRS2.pivot_table(
    values=['TE'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)     
CNLSSDb_CRS3
# Out:
#                 TE
# year          2016      2017      2018      2019
# 省份
# 上海市       0.106591  0.107916  0.108008  0.109293
# 云南省       0.102011  0.110192  0.120238  0.105355
# 内蒙古自治区    0.333872  0.361882  0.409520  0.449367
# 北京市       0.050636  0.048166  0.050768  0.049970
# 吉林省       0.113872  0.115554  0.111181  0.115379
# 四川省       0.175454  0.175272  0.167824  0.178495
# 天津市       0.083048  0.079849  0.087314  0.089790
# 宁夏回族自治区   0.077374  0.099220  0.108544  0.120334
# 安徽省       0.205206  0.209840  0.225931  0.231070
# 山东省       0.470928  0.455905  0.509205  0.528623
# 山西省       0.254511  0.276295  0.306737  0.320704
# 广东省       0.293076  0.307124  0.321283  0.331638
# 广西壮族自治区   0.119635  0.124985  0.131327  0.139753
# 新疆维吾尔自治区  0.209744  0.228549  0.238693  0.257784
# 江苏省       0.409758  0.416724  0.432354  0.455161
# 江西省       0.120841  0.126893  0.134042  0.137257
# 河北省       0.423578  0.410848  0.515009  0.516109
# 河南省       0.290428  0.279927  0.277816  0.260814
# 浙江省       0.210684  0.216394  0.220182  0.215985
# 海南省       0.022601  0.023910  0.023929  0.024424
# 湖北省       0.175997  0.183830  0.182571  0.200900
# 湖南省       0.166386  0.175425  0.173292  0.175936
# 甘肃省       0.086344  0.085279  0.092352  0.093200
# 福建省       0.120892  0.130505  0.148096  0.157522
# 贵州省       0.141056  0.144640  0.143304  0.147911
# 辽宁省       0.258607  0.271310  0.294962  0.301981
# 重庆市       0.087040  0.089311  0.091108  0.088538
# 陕西省       0.150334  0.148381  0.156427  0.167803
# 青海省       0.032014  0.030178  0.029451  0.029346
# 黑龙江省      0.152559  0.152174  0.140499  0.157580

# %%
CNLSSDb_VRS_SAME3 = CNLSSDb_VRS_SAME2.pivot_table(
    values=['TE'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
CNLSSDb_VRS_DIFF3 = CNLSSDb_VRS_DIFF2.pivot_table(
    values=['TE'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
CNLSSDb_VRS_DIFF3
# Out:
#                 TE
# year          2016      2017      2018      2019
# 省份
# 上海市       0.106591  0.107916  0.108008  0.109293
# 云南省       0.102011  0.110192  0.120238  0.105355
# 内蒙古自治区    0.333872  0.361882  0.409520  0.449367
# 北京市       0.050636  0.048166  0.050768  0.049970
# 吉林省       0.113872  0.115554  0.111182  0.115379
# 四川省       0.175454  0.175273  0.167824  0.178495
# 天津市       0.083048  0.079849  0.087314  0.089790
# 宁夏回族自治区   0.077374  0.099220  0.108544  0.120334
# 安徽省       0.205206  0.209840  0.225931  0.231070
# 山东省       0.470928  0.455905  0.509205  0.528622
# 山西省       0.254511  0.276295  0.306737  0.320705
# 广东省       0.293076  0.307124  0.321283  0.331638
# 广西壮族自治区   0.119636  0.124985  0.131327  0.139753
# 新疆维吾尔自治区  0.209744  0.228549  0.238693  0.257784
# 江苏省       0.409758  0.416724  0.432354  0.455161
# 江西省       0.120841  0.126893  0.134042  0.137257
# 河北省       0.423578  0.410848  0.515009  0.516109
# 河南省       0.290428  0.279927  0.277816  0.260814
# 浙江省       0.210684  0.216394  0.220183  0.215985
# 海南省       0.022601  0.023910  0.023929  0.024424
# 湖北省       0.175997  0.183830  0.182571  0.200900
# 湖南省       0.166386  0.175425  0.173292  0.175936
# 甘肃省       0.086344  0.085279  0.092352  0.093200
# 福建省       0.120892  0.130505  0.148096  0.157522
# 贵州省       0.141057  0.144640  0.143304  0.147911
# 辽宁省       0.258607  0.271310  0.294962  0.301981
# 重庆市       0.087040  0.089311  0.091108  0.088538
# 陕西省       0.150334  0.148381  0.156427  0.167803
# 青海省       0.032014  0.030178  0.029451  0.029346
# 黑龙江省      0.152559  0.152174  0.140500  0.157580

# %%
CNLSSDb_CRS3.to_markdown("table_CNLSSDb_CRS3.md")
CNLSSDb_VRS_SAME3.to_markdown("table_CNLSSDb_VRS_SAME3.md")
CNLSSDb_VRS_DIFF3.to_markdown("table_CNLSSDb_VRS_DIFF3.md")

# %%
SSS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 SSS
#
# NameError: name 'SSS' is not defined

# %% [markdown]
# ## CNLSDDFb

# %%
from deabook import CNLSSDFDDFweak,StoNED
from deabook.constant import FUN_PROD, OPT_LOCAL,RTS_VRS1,RTS_VRS2,RED_MOM,RED_QLE,RTS_CRS

# %%
def CNLSDDFb_CRS():

    model = CNLSSDFDDFweak.CNLSDDFweak(data,sent = "K L E=Y:CO2",  gy=[0], gx=[0,0,0],gb=[1],\
                                    fun=FUN_PROD,  rts=RTS_CRS)
    model.optimize( solver="mosek")

    rd = StoNED.StoNED(model)
    res=rd.get_technical_efficiency_ratio(RED_QLE)
    return res

CNLSDDFb_CRS=CNLSDDFb_CRS()
CNLSDDFb_CRS

# %%
def CNLSDDFb_VRS_SAME():

    model = CNLSSDFDDFweak.CNLSDDFweak(data,sent = "K L E=Y:CO2",  gy=[0], gx=[0,0,0],gb=[1],\
                                    fun=FUN_PROD,  rts=RTS_VRS1)
    model.optimize( solver="mosek")

    rd = StoNED.StoNED(model)
    res=rd.get_technical_efficiency_ratio(RED_QLE)
    return res

CNLSDDFb_VRS_SAME=CNLSDDFb_VRS_SAME()
CNLSDDFb_VRS_SAME

# %%
def CNLSDDFb_VRS_DIFF():

    model = CNLSSDFDDFweak.CNLSDDFweak(data,sent = "K L E=Y:CO2",  gy=[0], gx=[0,0,0],gb=[1],\
                                    fun=FUN_PROD,  rts=RTS_VRS2)
    model.optimize( solver="mosek")

    rd = StoNED.StoNED(model)
    res=rd.get_technical_efficiency_ratio(RED_QLE)
    return res

CNLSDDFb_VRS_DIFF=CNLSDDFb_VRS_DIFF()
CNLSDDFb_VRS_DIFF

# %%
CNLSDDFb_CRS2 = pd.DataFrame(CNLSDDFb_CRS,columns=['TE'])
CNLSDDFb_CRS2 = pd.concat([data,CNLSDDFb_CRS2], axis=1)
# CNLSDDFb_CRS2['TE'] = CNLSDDFb_CRS2['TE'].clip(lower=0)



CNLSDDFb_VRS_SAME2 =pd.DataFrame(CNLSDDFb_VRS_SAME,columns=['TE']) 
CNLSDDFb_VRS_SAME2 = pd.concat([data,CNLSDDFb_VRS_SAME2], axis=1)
# CNLSDDFb_VRS_SAME2['TE'] = CNLSDDFb_VRS_SAME2['TE'].clip(lower=0)


CNLSDDFb_VRS_DIFF2 =pd.DataFrame(CNLSDDFb_VRS_DIFF,columns=['TE']) 
CNLSDDFb_VRS_DIFF2 = pd.concat([data,CNLSDDFb_VRS_DIFF2], axis=1)
# CNLSDDFb_VRS_DIFF2['TE'] = CNLSDDFb_VRS_DIFF2['TE'].clip(lower=0)

# %%
## TE列小于0的值赋值为0

CNLSDDFb_CRS2

# %%
CNLSDDFb_CRS3 = CNLSDDFb_CRS2.pivot_table(
    values=['TE'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
CNLSDDFb_VRS_SAME3 =CNLSDDFb_VRS_SAME2.pivot_table(
    values=['TE'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
CNLSDDFb_VRS_DIFF3 = CNLSDDFb_VRS_DIFF2.pivot_table(
    values=['TE'],
    index=dmuname,
    columns='year',
    aggfunc='mean',
    fill_value=None,
    margins=False,
    dropna=True,
    margins_name='All',
    observed=False,
)

# %%
CNLSDDFb_CRS3.columns

# %%
CNLSDDFb_CRS3.sort_values(by=('TE', 2017),  )

# %%
CNLSDDFb_VRS_SAME3

# %%
CNLSDDFb_CRS3.to_markdown("table8.2_CNLSDDFb_CRS3.md")
CNLSDDFb_VRS_SAME3.to_markdown("table8.3_CNLSDDFb_VRS_SAME3.md")
CNLSDDFb_VRS_DIFF3.to_markdown("table8.4_CNLSDDFb_VRS_DIFF3.md")

# %%
SSS

# %% [markdown]
# ## figure

# %%
CNLSDDFb_VRS_DIFF3

# %%
CNLSDDFb_mean_year = CNLSDDFb_VRS_DIFF3['TE'].mean()

# %%
CNLSDDFb_mean_year

# %%
xtick2 = tuple(CNLSDDFb_mean_year.index)

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib notebook
# plt.figure(figsize=(1,1))
params = {
    'figure.figsize': '8, 4'
}
# plt.rcParams.update(params)
# plt.rc('font',family='Times New Roman')
from matplotlib import rcParams
rcParams['font.family'] = 'SimHei'


import numpy as np

# %%
fig, ax = plt.subplots() # 创建图形网格


ax.spines['top'].set_visible(False) # 使上边框不可见
ax.spines['right'].set_visible(False)
# ax2.spines['right'].set_visible(False)

################################ 绘图 #################################

n_groups = 4 # 样本的数目（ref，mut1-3）
index = np.arange(n_groups) # 转换为列表
bar_width = 0.5 # 设置柱子的宽度
# opacity = 0.8 # 设置柱子的透明度
error_config = {'ecolor': 'black','capsize' :2} # 设置误差线为黑色，宽度为2



# 画第一个样本的柱子
rects1 = ax.plot(index, CNLSDDFb_mean_year,
                color='darkblue',alpha = 0.8,linestyle = "dashed",marker = "s",label='CNLSDDFb'
            #      error_kw=error_config,
            #   edgecolor = 'white'
              )
# rects2 = ax.plot(index, MEFFCH_mean_year,
#                 color='olivedrab',alpha = 0.8,linestyle = "dashed",marker = "^",label='MEFFCH'
#             #      error_kw=error_config,
#             #   edgecolor = 'white'
#               )
# rects3 = ax.plot(index, MTECHCH_mean_year,
#                 color='orange',alpha = 0.8,linestyle = "dashed",marker = "+",label='MTECHCH'
#             #      error_kw=error_config,
#             #   edgecolor = 'white'
#               )
###########################################333

# ax.set_xlabel('Hours in 4 ℃')
ax.set_ylabel( r'$\mathregular{碳排放效率}$')
#  r'$Difficulty of reducing emissions \gamma$' 
# ax.set_title('Creat by python')
ax.set_xticks(index )
ax.set_xticklabels(xtick2)
# ax2.set_xlabel('Relative gene expression')
# ax.spines["bottom"].set_position(("data",0))
plt.legend()#borderaxespad=10,loc='upper right', fontsize='x-large'mode='expand'

plt.xticks(rotation=80)    # x 轴刻度添加80度旋转
# ax.legend(frameon=False,loc='best',ncol = 1)
if kind=="province":
   plt.savefig("chap8分年份碳排放效率-省.png", dpi=900, bbox_inches = 'tight')
else:
   plt.savefig("chap8分年份碳排放效率-国.png", dpi=900, bbox_inches = 'tight')
plt.show()

# %%
CNLSDDFb_mean_cou = CNLSDDFb_VRS_DIFF3['TE'].mean(axis=1)

# %%
CNLSDDFb_mean_cou

# %%
CNLSDDFb_mean_cou=CNLSDDFb_mean_cou.sort_values(ascending=False)

# %%
CNLSDDFb_mean_cou

# %%
xtick2 = tuple(CNLSDDFb_mean_cou.index)
xtick2

# %%
fig, ax = plt.subplots() # 创建图形网格


ax.spines['top'].set_visible(False) # 使上边框不可见
ax.spines['right'].set_visible(False)
# ax2.spines['right'].set_visible(False)

################################ 绘图 #################################
if kind=="province":
   n_groups = 30 # 样本的数目（ref，mut1-3）
else:
   n_groups = 33  

index = np.arange(n_groups) # 转换为列表
bar_width = 0.5 # 设置柱子的宽度
# opacity = 0.8 # 设置柱子的透明度
error_config = {'ecolor': 'black','capsize' :2} # 设置误差线为黑色，宽度为2



# 画第一个样本的柱子
rects1 = ax.bar(index-bar_width/1.5, CNLSDDFb_mean_cou,
                bar_width/2,
                color='darkblue',alpha = 0.8,
                 error_kw=error_config,
              edgecolor = 'white',label='CNLSDDFb'
              )
# rects2 = ax.bar(index , MEFFCH_mean_cou,
#                 bar_width/2,
#                 color='olivedrab',alpha = 0.8,
#                  error_kw=error_config,
#               edgecolor = 'white',label='MEFFCH'
#               )

# rects3 = ax.bar(index+bar_width/1.5, MTECHCH_mean_cou,
#                 bar_width/2,
#                 color='orange',alpha = 0.8,
#                  error_kw=error_config,
#               edgecolor = 'white',label='MTECHCH'
#               )
###########################################333

# ax.set_xlabel('Hours in 4 ℃')
ax.set_ylabel( r'$\mathregular{碳排放效率}$')
#  r'$Difficulty of reducing emissions \gamma$' 
# ax.set_title('Creat by python')
ax.set_xticks(index )
ax.set_xticklabels(xtick2)
# ax2.set_xlabel('Relative gene expression')
# ax.spines["bottom"].set_position(("data",0))
plt.legend(loc='upper left')#borderaxespad=10,loc='upper right', fontsize='x-large'mode='expand'

plt.xticks(rotation=80)    # x 轴刻度添加80度旋转
# ax.legend(frameon=False,loc='best',ncol = 1)
if kind=="province":
   plt.savefig("chap8分省份碳排放效率.png", dpi=900, bbox_inches = 'tight')
else:
   plt.savefig("chap8分国家碳排放效率.png", dpi=900, bbox_inches = 'tight')

plt.show()
